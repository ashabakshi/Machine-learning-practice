# %% [markdown]
# # Imporitng the necessary library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('placement (3).csv')

# %%
# df

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
plt.scatter(df['cgpa'],df['package']);

# %%
df.corr()
# Out:
#              cgpa   package
# cgpa     1.000000  0.880692
# package  0.880692  1.000000

# %%
sns.heatmap(df.corr(),annot=True);

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x=df[['cgpa']] # x can be multuiple inputs (2D)

# %%
y=df['package'] # alwsy we a single input (1d)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (160, 1) (160,)
# (40, 1) (40,)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=l.coef_
m
# Out:
# array([0.55795197])

# %%
c=l.intercept_
c
# Out:
# -0.8961119222429166

# %%
x_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
y_pred_test=l.predict(x_test)
y_pred_train=l.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae , r2_score

# %%
mse(y_train,y_pred_train)
# Out:
# 0.10345460923452961

# %%
np.sqrt(mse(y_train,y_pred_train))
# Out:
# 0.3216436059282535

# %%
mae(y_train,y_pred_train)
# Out:
# 0.2529676082975413
