# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df['Age']=2025-df['Year']
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Age
# 0        Dealer       Manual      0   11
# 1        Dealer       Manual      0   12
# 2        Dealer       Manual      0    8
# 3        Dealer       Manual      0   14
# 4        Dealer       Manual      0   11
# ..          ...          ...    ...  ...
# 296      Dealer       Manual      0    9
# 297      Dealer       Manual      0   10
# 298      Dealer       Manual      0   16
# 299      Dealer       Manual      0    8
# 300      Dealer       Manual      0    9
#
# [301 rows x 10 columns]

# %%
df.drop(columns=['Year'],inplace=True)

# %%
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz           3.35           5.59       27000    Petrol      Dealer
# 1        sx4           4.75           9.54       43000    Diesel      Dealer
# 2       ciaz           7.25           9.85        6900    Petrol      Dealer
# 3    wagon r           2.85           4.15        5200    Petrol      Dealer
# 4      swift           4.60           6.87       42450    Diesel      Dealer
# ..       ...            ...            ...         ...       ...         ...
# 296     city           9.50          11.60       33988    Diesel      Dealer
# 297     brio           4.00           5.90       60000    Petrol      Dealer
# 298     city           3.35          11.00       87934    Petrol      Dealer
# 299     city          11.50          12.50        9000    Diesel      Dealer
# 300     brio           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   11
# 1         Manual      0   12
# 2         Manual      0    8
# 3         Manual      0   14
# 4         Manual      0   11
# ..           ...    ...  ...
# 296       Manual      0    9
# 297       Manual      0   10
# 298       Manual      0   16
# 299       Manual      0    8
# 300       Manual      0    9
#
# [301 rows x 9 columns]

# %%
df = pd.get_dummies(df,columns=['Fuel_Type','Seller_Type','Transmission'],drop_first=True)
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   11             False
# 1             4.75           9.54       43000      0   12              True
# 2             7.25           9.85        6900      0    8             False
# 3             2.85           4.15        5200      0   14             False
# 4             4.60           6.87       42450      0   11              True
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    9              True
# 297           4.00           5.90       60000      0   10             False
# 298           3.35          11.00       87934      0   16             False
# 299          11.50          12.50        9000      0    8              True
# 300           5.30           5.90        5464      0    9             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  \
# 0                True                   False                 True
# 1               False                   False                 True
# 2                True                   False                 True
# 3                True                   False                 True
# 4               False                   False                 True
# ..                ...                     ...                  ...
# 296             False                   False                 True
# 297              True                   False                 True
# 298              True                   False                 True
# 299             False                   False                 True
# 300              True                   False                 True
#
#      Car_Name_Activa 3g  ...  Car_Name_land cruiser  Car_Name_omni  \
# 0                 False  ...                  False          False
# 1                 False  ...                  False          False
# 2                 False  ...                  False          False
# 3                 False  ...                  False          False
# 4                 False  ...                  False          False
# ..                  ...  ...                    ...            ...
# 296               False  ...                  False          False
# 297               False  ...                  False          False
# 298               False  ...                  False          False
# 299               False  ...                  False          False
# 300               False  ...                  False          False
#
#      Car_Name_ritz  Car_Name_s cross  Car_Name_swift  Car_Name_sx4  \
# 0             True             False           False         False
# 1            False             False           False          True
# 2            False             False           False         False
# 3            False             False           False         False
# 4            False             False            True         False
# ..             ...               ...             ...           ...
# 296          False             False           False         False
# 297          False             False           False         False
# 298          False             False           False         False
# 299          False             False           False         False
# 300          False             False           False         False
#
#      Car_Name_verna  Car_Name_vitara brezza  Car_Name_wagon r  Car_Name_xcent
# 0             False                   False             False           False
# 1             False                   False             False           False
# 2             False                   False             False           False
# 3             False                   False              True           False
# 4             False                   False             False           False
# ..              ...                     ...               ...             ...
# 296           False                   False             False           False
# 297           False                   False             False           False
# 298           False                   False             False           False
# 299           False                   False             False           False
# 300           False                   False             False           False
#
# [301 rows x 106 columns]

# %%
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0       ritz           3.35           5.59       27000      0   11
# 1        sx4           4.75           9.54       43000      0   12
# 2       ciaz           7.25           9.85        6900      0    8
# 3    wagon r           2.85           4.15        5200      0   14
# 4      swift           4.60           6.87       42450      0   11
# ..       ...            ...            ...         ...    ...  ...
# 296     city           9.50          11.60       33988      0    9
# 297     brio           4.00           5.90       60000      0   10
# 298     city           3.35          11.00       87934      0   16
# 299     city          11.50          12.50        9000      0    8
# 300     brio           5.30           5.90        5464      0    9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False              True                   False
# 4                True             False                   False
# ..                ...               ...                     ...
# 296              True             False                   False
# 297             False              True                   False
# 298             False              True                   False
# 299              True             False                   False
# 300             False              True                   False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [301 rows x 10 columns]

# %%
# df['Car_Name'].nunique()

# %%
df1 = df.groupby(['Car_Name'])['Selling_Price'].mean().reset_index().rename(columns = {'Selling_Price':'avg_price'})
df1
# Out:
#              Car_Name  avg_price
# 0                 800   0.350000
# 1           Activa 3g   0.310000
# 2           Activa 4g   0.400000
# 3       Bajaj  ct 100   0.180000
# 4   Bajaj Avenger 150   0.750000
# ..                ...        ...
# 93                sx4   3.158333
# 94              verna   6.107857
# 95      vitara brezza   9.250000
# 96            wagon r   2.512500
# 97              xcent   4.966667
#
# [98 rows x 2 columns]

# %%
df1 = pd.merge(df,df1,on='Car_Name',how='inner')
df1
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0       ritz           3.35           5.59       27000      0   11
# 1        sx4           4.75           9.54       43000      0   12
# 2       ciaz           7.25           9.85        6900      0    8
# 3    wagon r           2.85           4.15        5200      0   14
# 4      swift           4.60           6.87       42450      0   11
# ..       ...            ...            ...         ...    ...  ...
# 296     city           9.50          11.60       33988      0    9
# 297     brio           4.00           5.90       60000      0   10
# 298     city           3.35          11.00       87934      0   16
# 299     city          11.50          12.50        9000      0    8
# 300     brio           5.30           5.90        5464      0    9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False              True                   False
# 4                True             False                   False
# ..                ...               ...                     ...
# 296              True             False                   False
# 297             False              True                   False
# 298             False              True                   False
# 299              True             False                   False
# 300             False              True                   False
#
#      Transmission_Manual  avg_price
# 0                   True   2.862500
# 1                   True   3.158333
# 2                   True   7.472222
# 3                   True   2.512500
# 4                   True   4.540000
# ..                   ...        ...
# 296                 True   7.419231
# 297                 True   4.745000
# 298                 True   7.419231
# 299                 True   7.419231
# 300                 True   4.745000
#
# [301 rows x 11 columns]

# %%
df1.drop(columns=['Car_Name'],inplace=True)

# %%
df1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   11             False
# 1             4.75           9.54       43000      0   12              True
# 2             7.25           9.85        6900      0    8             False
# 3             2.85           4.15        5200      0   14             False
# 4             4.60           6.87       42450      0   11              True
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    9              True
# 297           4.00           5.90       60000      0   10             False
# 298           3.35          11.00       87934      0   16             False
# 299          11.50          12.50        9000      0    8              True
# 300           5.30           5.90        5464      0    9             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  avg_price
# 0                True                   False                 True   2.862500
# 1               False                   False                 True   3.158333
# 2                True                   False                 True   7.472222
# 3                True                   False                 True   2.512500
# 4               False                   False                 True   4.540000
# ..                ...                     ...                  ...        ...
# 296             False                   False                 True   7.419231
# 297              True                   False                 True   4.745000
# 298              True                   False                 True   7.419231
# 299             False                   False                 True   7.419231
# 300              True                   False                 True   4.745000
#
# [301 rows x 10 columns]

# %%
sns.heatmap(df.corr(),annot=True);
# Out:
# Error in callback <function flush_figures at 0x000001F447EA6980> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %%
X = df1.drop(columns=['Selling_Price'])
y=df1['Selling_Price']

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             5.59       27000      0   11             False
# 1             9.54       43000      0   12              True
# 2             9.85        6900      0    8             False
# 3             4.15        5200      0   14             False
# 4             6.87       42450      0   11              True
# ..             ...         ...    ...  ...               ...
# 296          11.60       33988      0    9              True
# 297           5.90       60000      0   10             False
# 298          11.00       87934      0   16             False
# 299          12.50        9000      0    8              True
# 300           5.90        5464      0    9             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  \
# 0                True                   False                 True
# 1               False                   False                 True
# 2                True                   False                 True
# 3                True                   False                 True
# 4               False                   False                 True
# ..                ...                     ...                  ...
# 296             False                   False                 True
# 297              True                   False                 True
# 298              True                   False                 True
# 299             False                   False                 True
# 300              True                   False                 True
#
#      Car_Name_Activa 3g  Car_Name_Activa 4g  ...  Car_Name_land cruiser  \
# 0                 False               False  ...                  False
# 1                 False               False  ...                  False
# 2                 False               False  ...                  False
# 3                 False               False  ...                  False
# 4                 False               False  ...                  False
# ..                  ...                 ...  ...                    ...
# 296               False               False  ...                  False
# 297               False               False  ...                  False
# 298               False               False  ...                  False
# 299               False               False  ...                  False
# 300               False               False  ...                  False
#
#      Car_Name_omni  Car_Name_ritz  Car_Name_s cross  Car_Name_swift  \
# 0            False           True             False           False
# 1            False          False             False           False
# 2            False          False             False           False
# 3            False          False             False           False
# 4            False          False             False            True
# ..             ...            ...               ...             ...
# 296          False          False             False           False
# 297          False          False             False           False
# 298          False          False             False           False
# 299          False          False             False           False
# 300          False          False             False           False
#
#      Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  Car_Name_wagon r  \
# 0           False           False                   False             False
# 1            True           False                   False             False
# 2           False           False                   False             False
# 3           False           False                   False              True
# 4           False           False                   False             False
# ..            ...             ...                     ...               ...
# 296         False           False                   False             False
# 297         False           False                   False             False
# 298         False           False                   False             False
# 299         False           False                   False             False
# 300         False           False                   False             False
#
#      Car_Name_xcent
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 296           False
# 297           False
# 298           False
# 299           False
# 300           False
#
# [301 rows x 105 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()
x_scaled = st.fit_transform(X)
x_scaled
# Out:
# array([[-0.23621461, -0.25622446, -0.17450057, ..., -0.05773503,
#         -0.11605177, -0.10033501],
#        [ 0.22150462,  0.1559105 , -0.17450057, ..., -0.05773503,
#         -0.11605177, -0.10033501],
#        [ 0.25742689, -0.77396901, -0.17450057, ..., -0.05773503,
#         -0.11605177, -0.10033501],
#        ...,
#        [ 0.39068691,  1.31334003, -0.17450057, ..., -0.05773503,
#         -0.11605177, -0.10033501],
#        [ 0.56450434, -0.7198763 , -0.17450057, ..., -0.05773503,
#         -0.11605177, -0.10033501],
#        [-0.20029235, -0.81095812, -0.17450057, ..., -0.05773503,
#         -0.11605177, -0.10033501]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test ,y_train , y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=2)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (240, 105) (240,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 5.26133631e+00, -1.45469179e-01,  7.11776604e-02, -1.70843343e+00,
#         1.39785429e+00,  1.03901243e+00, -1.26012986e-01, -1.00253760e-01,
#        -3.35772418e-01, -4.55897185e-01, -3.69519659e-01, -3.93652195e-01,
#         2.55351296e-15, -7.48724500e-01, -5.24392351e-01,  3.55271368e-15,
#        -8.32667268e-16, -3.91099783e-01, -4.16743843e-01, -3.36957851e-01,
#         1.04308923e-14, -3.65362461e-01, -4.29191534e-01, -4.95598036e-01,
#        -3.92807548e-01, -2.66453526e-15, -3.30755924e-01, -4.44532072e-01,
#        -3.09817389e-01, -6.55031585e-15, -2.61724118e-01, -5.42101086e-16,
#        -5.46719046e-01, -3.94092513e-01, -3.99048633e-01, -2.77555756e-17,
#        -3.22750583e-02, -4.21929576e-01, -6.36247850e-01, -6.95710929e-01,
#        -4.30197228e-01, -3.06941971e-01,  1.11026211e-16, -3.61565523e-01,
#        -4.59228393e-01, -4.33777593e-01, -2.52712623e-01, -3.98484953e-01,
#         6.94277600e-18, -5.74131154e-01, -3.76981224e-01, -3.85647194e-01,
#        -3.89585425e-01, -9.35421902e-01, -3.18463824e-01, -6.47244554e-01,
#        -6.12974803e-01, -1.60358245e-01, -5.94951879e-01, -3.37277579e-01,
#         1.11108201e-17, -2.17456626e-17, -2.22029777e-01, -4.10033096e-01,
#        -5.39818396e-01, -3.03599130e-17, -2.78947411e-01, -6.68879894e-01,
#        -1.05783803e-17, -4.21328202e-01, -7.44137593e-01, -9.73436011e-01,
#        -3.76613356e-01, -9.96418361e-01, -7.94376058e-01, -9.74914710e-01,
#        -1.70350053e+00, -3.51580326e-01, -1.84007770e+00, -3.93862240e-01,
#        -6.93680818e-01, -3.92830203e-01, -9.26600825e-01, -9.37215616e-01,
#        -6.66826486e-01, -6.58464051e-01, -4.38328221e-01, -6.80546439e-01,
#        -1.22237845e+00, -9.04477855e-01, -5.57542053e-01, -9.59043255e-01,
#        -3.77331839e-01, -6.41541149e-01, -9.15260802e-01, -1.49243012e+00,
#        -3.00875580e-01, -6.38822980e-01,  8.36805271e-18, -7.16697514e-01,
#        -7.07635495e-01, -1.24256151e+00, -3.59191153e-01, -4.52602639e-01,
#        -6.24861008e-01])

# %%
lr.intercept_
# Out:
# 4.974853838125811

# %%
y_pred_train = lr.predict(x_train)

# %%
y_pred_test = lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error , r2_score

# %%
print(mean_squared_error(y_train,y_pred_train))
print(mean_squared_error(y_test,y_pred_test))
# Out:
# 1.5825512269104225
# 9.98188527300544

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.9426732426518523

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.45651634276884534

# %%
df.select_dtypes(include=np.number).corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner       Age
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# Age                -0.236141       0.047584    0.524342  0.182104  1.000000

# %%
d = df.select_dtypes(include=np.number)
d
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age
# 0             3.35           5.59       27000      0   11
# 1             4.75           9.54       43000      0   12
# 2             7.25           9.85        6900      0    8
# 3             2.85           4.15        5200      0   14
# 4             4.60           6.87       42450      0   11
# ..             ...            ...         ...    ...  ...
# 296           9.50          11.60       33988      0    9
# 297           4.00           5.90       60000      0   10
# 298           3.35          11.00       87934      0   16
# 299          11.50          12.50        9000      0    8
# 300           5.30           5.90        5464      0    9
#
# [301 rows x 5 columns]

# %%
sns.heatmap(d.corr(),annot=True)
# Out:
# <Axes: >

# %%
num = df.select_dtypes(include=np.number)
num
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age
# 0             3.35           5.59       27000      0   11
# 1             4.75           9.54       43000      0   12
# 2             7.25           9.85        6900      0    8
# 3             2.85           4.15        5200      0   14
# 4             4.60           6.87       42450      0   11
# ..             ...            ...         ...    ...  ...
# 296           9.50          11.60       33988      0    9
# 297           4.00           5.90       60000      0   10
# 298           3.35          11.00       87934      0   16
# 299          11.50          12.50        9000      0    8
# 300           5.30           5.90        5464      0    9
#
# [301 rows x 5 columns]

# %%
num.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner       Age
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# Age                -0.236141       0.047584    0.524342  0.182104  1.000000

# %%
for i in df:
    if df[i].dtype=='O':
        print(i,'.......',df[i].nunique())
        print(df[i].unique())
# Out:
# Car_Name ....... 98
# ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
#  'Honda Activa 4G' 'TVS Sport ' 'Honda Dream Yuga '
#  'Bajaj Avenger Street 220' 'Hero Splender iSmart' 'Activa 3g'
#  'Hero Passion Pro' 'Honda CB Trigger' 'Yamaha FZ S '
#  'Bajaj Pulsar 135 LS' 'Activa 4g' 'Honda CB Unicorn'
#  'Hero Honda CBZ extreme' 'Honda Karizma' 'Honda Activa 125' 'TVS Jupyter'
#  'Hero Honda Passion Pro' 'Hero Splender Plus' 'Honda CB Shine'
#  'Bajaj Discover 100' 'Suzuki Access 125' 'TVS Wego' 'Honda CB twister'
#  'Hero Glamour' 'Hero Super Splendor' 'Bajaj Discover 125' 'Hero Hunk'
#  'Hero  Ignitor Disc' 'Hero  CBZ Xtreme' 'Bajaj  ct 100' 'i20' 'grand i10'
#  'i10' 'eon' 'xcent' 'elantra' 'creta' 'verna' 'city' 'brio' 'amaze'
#  'jazz']
# Fuel_Type ....... 3
# ['Petrol' 'Diesel' 'CNG']
# Seller_Type ....... 2
# ['Dealer' 'Individual']
# Transmission ....... 2
# ['Manual' 'Automatic']

# %%
sns.heatmap(num.corr(),annot=True);

# %%
for i in df.iloc[:,1:]:
    if df[i].dtype=='object':
        print(i,'........',df[i].nunique(),'......',df[i].unique())
# Out:
# Fuel_Type ........ 3 ...... ['Petrol' 'Diesel' 'CNG']
# Seller_Type ........ 2 ...... ['Dealer' 'Individual']
# Transmission ........ 2 ...... ['Manual' 'Automatic']

# %%
num.corr()
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner       Age
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# Age                -0.236141       0.047584    0.524342  0.182104  1.000000

# %%
sns.heatmap(num.corr(),annot =True);

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   11
# 1         Manual      0   12
# 2         Manual      0    8
# 3         Manual      0   14
# 4         Manual      0   11
# ..           ...    ...  ...
# 296       Manual      0    9
# 297       Manual      0   10
# 298       Manual      0   16
# 299       Manual      0    8
# 300       Manual      0    9
#
# [301 rows x 8 columns]

# %%
for i in df:
    if df[i].dtype=='O':
        print(i,'....',df[i].nunique())
# Out:
# Car_Name .... 98
# Fuel_Type .... 3
# Seller_Type .... 2
# Transmission .... 2

# %%
for i in df.select_dtypes(include = 'O'):
    print(i,'.....',df[i].nunique())
# Out:
# Car_Name ..... 98
# Fuel_Type ..... 3
# Seller_Type ..... 2
# Transmission ..... 2

# %%
# Categorical data

#.1 ordinal - (label encoding)
#2. Nominal -  (one hot encoding)

# %%
df['Car_Name'].nunique()
# Out:
# 98

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
#        'Yamaha FZ  v 2.0', 'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 220 F',
#        'TVS Apache RTR 180', 'Hero Passion X pro', 'Bajaj Pulsar NS 200',
#        'Yamaha Fazer ', 'Honda Activa 4G', 'TVS Sport ',
#        'Honda Dream Yuga ', 'Bajaj Avenger Street 220',
#        'Hero Splender iSmart', 'Activa 3g', 'Hero Passion Pro',
#        'Honda CB Trigger', 'Yamaha FZ S ', 'Bajaj Pulsar 135 LS',
#        'Activa 4g', 'Honda CB Unicorn', 'Hero Honda CBZ extreme',
#        'Honda Karizma', 'Honda Activa 125', 'TVS Jupyter',
#        'Hero Honda Passion Pro', 'Hero Splender Plus', 'Honda CB Shine',
#        'Bajaj Discover 100', 'Suzuki Access 125', 'TVS Wego',
#        'Honda CB twister', 'Hero Glamour', 'Hero Super Splendor',
#        'Bajaj Discover 125', 'Hero Hunk', 'Hero  Ignitor Disc',
#        'Hero  CBZ Xtreme', 'Bajaj  ct 100', 'i20', 'grand i10', 'i10',
#        'eon', 'xcent', 'elantra', 'creta', 'verna', 'city', 'brio',
#        'amaze', 'jazz'], dtype=object)

# %%
for i in df:
    if df[i].dtype=='object':
        print(i,'......',df[i].nunique(),'.....',df[i].unique())
# Out:
# Car_Name ...... 98 ..... ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
#  'Honda Activa 4G' 'TVS Sport ' 'Honda Dream Yuga '
#  'Bajaj Avenger Street 220' 'Hero Splender iSmart' 'Activa 3g'
#  'Hero Passion Pro' 'Honda CB Trigger' 'Yamaha FZ S '
#  'Bajaj Pulsar 135 LS' 'Activa 4g' 'Honda CB Unicorn'
#  'Hero Honda CBZ extreme' 'Honda Karizma' 'Honda Activa 125' 'TVS Jupyter'
#  'Hero Honda Passion Pro' 'Hero Splender Plus' 'Honda CB Shine'
#  'Bajaj Discover 100' 'Suzuki Access 125' 'TVS Wego' 'Honda CB twister'
#  'Hero Glamour' 'Hero Super Splendor' 'Bajaj Discover 125' 'Hero Hunk'
#  'Hero  Ignitor Disc' 'Hero  CBZ Xtreme' 'Bajaj  ct 100' 'i20' 'grand i10'
#  'i10' 'eon' 'xcent' 'elantra' 'creta' 'verna' 'city' 'brio' 'amaze'
#  'jazz']
# Fuel_Type ...... 3 ..... ['Petrol' 'Diesel' 'CNG']
# Seller_Type ...... 2 ..... ['Dealer' 'Individual']
# Transmission ...... 2 ..... ['Manual' 'Automatic']

# %%
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz           3.35           5.59       27000    Petrol      Dealer
# 1        sx4           4.75           9.54       43000    Diesel      Dealer
# 2       ciaz           7.25           9.85        6900    Petrol      Dealer
# 3    wagon r           2.85           4.15        5200    Petrol      Dealer
# 4      swift           4.60           6.87       42450    Diesel      Dealer
# ..       ...            ...            ...         ...       ...         ...
# 296     city           9.50          11.60       33988    Diesel      Dealer
# 297     brio           4.00           5.90       60000    Petrol      Dealer
# 298     city           3.35          11.00       87934    Petrol      Dealer
# 299     city          11.50          12.50        9000    Diesel      Dealer
# 300     brio           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age
# 0         Manual      0   11
# 1         Manual      0   12
# 2         Manual      0    8
# 3         Manual      0   14
# 4         Manual      0   11
# ..           ...    ...  ...
# 296       Manual      0    9
# 297       Manual      0   10
# 298       Manual      0   16
# 299       Manual      0    8
# 300       Manual      0    9
#
# [301 rows x 9 columns]

# %%
# categorical 2 types
# 1. ordinal - certain order (label encoding)
# 2. Nominal -  One Hot Encoding

# %%
df1=pd.get_dummies(df,columns=['Fuel_Type','Seller_Type','Transmission'],drop_first=True)
df1
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0       ritz           3.35           5.59       27000      0   11
# 1        sx4           4.75           9.54       43000      0   12
# 2       ciaz           7.25           9.85        6900      0    8
# 3    wagon r           2.85           4.15        5200      0   14
# 4      swift           4.60           6.87       42450      0   11
# ..       ...            ...            ...         ...    ...  ...
# 296     city           9.50          11.60       33988      0    9
# 297     brio           4.00           5.90       60000      0   10
# 298     city           3.35          11.00       87934      0   16
# 299     city          11.50          12.50        9000      0    8
# 300     brio           5.30           5.90        5464      0    9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False              True                   False
# 4                True             False                   False
# ..                ...               ...                     ...
# 296              True             False                   False
# 297             False              True                   False
# 298             False              True                   False
# 299              True             False                   False
# 300             False              True                   False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [301 rows x 10 columns]

# %%
df1
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0       ritz           3.35           5.59       27000      0   11
# 1        sx4           4.75           9.54       43000      0   12
# 2       ciaz           7.25           9.85        6900      0    8
# 3    wagon r           2.85           4.15        5200      0   14
# 4      swift           4.60           6.87       42450      0   11
# ..       ...            ...            ...         ...    ...  ...
# 296     city           9.50          11.60       33988      0    9
# 297     brio           4.00           5.90       60000      0   10
# 298     city           3.35          11.00       87934      0   16
# 299     city          11.50          12.50        9000      0    8
# 300     brio           5.30           5.90        5464      0    9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False              True                   False
# 4                True             False                   False
# ..                ...               ...                     ...
# 296              True             False                   False
# 297             False              True                   False
# 298             False              True                   False
# 299              True             False                   False
# 300             False              True                   False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [301 rows x 10 columns]

# %%
df1
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0       ritz           3.35           5.59       27000      0   11
# 1        sx4           4.75           9.54       43000      0   12
# 2       ciaz           7.25           9.85        6900      0    8
# 3    wagon r           2.85           4.15        5200      0   14
# 4      swift           4.60           6.87       42450      0   11
# ..       ...            ...            ...         ...    ...  ...
# 296     city           9.50          11.60       33988      0    9
# 297     brio           4.00           5.90       60000      0   10
# 298     city           3.35          11.00       87934      0   16
# 299     city          11.50          12.50        9000      0    8
# 300     brio           5.30           5.90        5464      0    9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False              True                   False
# 4                True             False                   False
# ..                ...               ...                     ...
# 296              True             False                   False
# 297             False              True                   False
# 298             False              True                   False
# 299              True             False                   False
# 300             False              True                   False
#
#      Transmission_Manual
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ..                   ...
# 296                 True
# 297                 True
# 298                 True
# 299                 True
# 300                 True
#
# [301 rows x 10 columns]

# %%
df1.head(2)
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0     ritz           3.35           5.59       27000      0   11
# 1      sx4           4.75           9.54       43000      0   12
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0             False              True                   False
# 1              True             False                   False
#
#    Transmission_Manual
# 0                 True
# 1                 True

# %%
df2=df1.groupby(['Car_Name'])['Selling_Price'].mean().reset_index().rename(columns={'Selling_Price':'car'})
df2
# Out:
#              Car_Name       car
# 0                 800  0.350000
# 1           Activa 3g  0.310000
# 2           Activa 4g  0.400000
# 3       Bajaj  ct 100  0.180000
# 4   Bajaj Avenger 150  0.750000
# ..                ...       ...
# 93                sx4  3.158333
# 94              verna  6.107857
# 95      vitara brezza  9.250000
# 96            wagon r  2.512500
# 97              xcent  4.966667
#
# [98 rows x 2 columns]

# %%
df3=pd.merge(df1,df2,how='inner',on='Car_Name')
df3
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven  Owner  Age  \
# 0       ritz           3.35           5.59       27000      0   11
# 1        sx4           4.75           9.54       43000      0   12
# 2       ciaz           7.25           9.85        6900      0    8
# 3    wagon r           2.85           4.15        5200      0   14
# 4      swift           4.60           6.87       42450      0   11
# ..       ...            ...            ...         ...    ...  ...
# 296     city           9.50          11.60       33988      0    9
# 297     brio           4.00           5.90       60000      0   10
# 298     city           3.35          11.00       87934      0   16
# 299     city          11.50          12.50        9000      0    8
# 300     brio           5.30           5.90        5464      0    9
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0               False              True                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False              True                   False
# 4                True             False                   False
# ..                ...               ...                     ...
# 296              True             False                   False
# 297             False              True                   False
# 298             False              True                   False
# 299              True             False                   False
# 300             False              True                   False
#
#      Transmission_Manual       car
# 0                   True  2.862500
# 1                   True  3.158333
# 2                   True  7.472222
# 3                   True  2.512500
# 4                   True  4.540000
# ..                   ...       ...
# 296                 True  7.419231
# 297                 True  4.745000
# 298                 True  7.419231
# 299                 True  7.419231
# 300                 True  4.745000
#
# [301 rows x 11 columns]

# %%
df3.drop(columns=['Car_Name'],inplace=True)

# %%
df3
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000      0   11             False
# 1             4.75           9.54       43000      0   12              True
# 2             7.25           9.85        6900      0    8             False
# 3             2.85           4.15        5200      0   14             False
# 4             4.60           6.87       42450      0   11              True
# ..             ...            ...         ...    ...  ...               ...
# 296           9.50          11.60       33988      0    9              True
# 297           4.00           5.90       60000      0   10             False
# 298           3.35          11.00       87934      0   16             False
# 299          11.50          12.50        9000      0    8              True
# 300           5.30           5.90        5464      0    9             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual       car
# 0                True                   False                 True  2.862500
# 1               False                   False                 True  3.158333
# 2                True                   False                 True  7.472222
# 3                True                   False                 True  2.512500
# 4               False                   False                 True  4.540000
# ..                ...                     ...                  ...       ...
# 296             False                   False                 True  7.419231
# 297              True                   False                 True  4.745000
# 298              True                   False                 True  7.419231
# 299             False                   False                 True  7.419231
# 300              True                   False                 True  4.745000
#
# [301 rows x 10 columns]

# %%
sns.heatmap(df3.corr(),annot=True)
# Out:
# <Axes: >

# %%
# df1

# %%
X=df3.drop(columns=['Selling_Price'])
y=df3['Selling_Price']

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  Age  Fuel_Type_Diesel  \
# 0             5.59       27000      0   11             False
# 1             9.54       43000      0   12              True
# 2             9.85        6900      0    8             False
# 3             4.15        5200      0   14             False
# 4             6.87       42450      0   11              True
# ..             ...         ...    ...  ...               ...
# 296          11.60       33988      0    9              True
# 297           5.90       60000      0   10             False
# 298          11.00       87934      0   16             False
# 299          12.50        9000      0    8              True
# 300           5.90        5464      0    9             False
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual       car
# 0                True                   False                 True  2.862500
# 1               False                   False                 True  3.158333
# 2                True                   False                 True  7.472222
# 3                True                   False                 True  2.512500
# 4               False                   False                 True  4.540000
# ..                ...                     ...                  ...       ...
# 296             False                   False                 True  7.419231
# 297              True                   False                 True  4.745000
# 298              True                   False                 True  7.419231
# 299             False                   False                 True  7.419231
# 300              True                   False                 True  4.745000
#
# [301 rows x 9 columns]

# %%
# X=df1.drop(columns=['Selling_Price'])
# y=df1['Selling_Price']

# %%
from sklearn.preprocessing import StandardScaler

# %%
# X

# %%
st=StandardScaler()
x_scaled=st.fit_transform(X)
x_scaled
# Out:
# array([[-0.23621461, -0.25622446, -0.17450057, ..., -0.73728539,
#          0.39148015, -0.39671534],
#        [ 0.22150462,  0.1559105 , -0.17450057, ..., -0.73728539,
#          0.39148015, -0.33147079],
#        [ 0.25742689, -0.77396901, -0.17450057, ..., -0.73728539,
#          0.39148015,  0.61993571],
#        ...,
#        [ 0.39068691,  1.31334003, -0.17450057, ..., -0.73728539,
#          0.39148015,  0.60824871],
#        [ 0.56450434, -0.7198763 , -0.17450057, ..., -0.73728539,
#          0.39148015,  0.60824871],
#        [-0.20029235, -0.81095812, -0.17450057, ..., -0.73728539,
#          0.39148015,  0.01846057]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=1)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (240, 9) (240,)
# (61, 9) (61,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_scaled.shape
# Out:
# (301, 9)

# %%
lr.coef_
# Out:
# array([ 2.69215621, -0.20729746,  0.09929783, -1.17598968,  0.49571499,
#        -0.02234284, -0.37628188, -0.59221912,  1.40181488])

# %%
lr.intercept_
# Out:
# 4.6953172944868715

# %%
from sklearn.metrics import r2_score

# %%
y_pred_train=lr.predict(x_train)
y_pred_test=lr.predict(x_test)

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.8915572561110516

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.9035789494878802
