# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X,y = make_regression(n_samples=200, n_features=1, n_informative=1, n_targets=1,noise=150,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
# Lets apply OLS
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
#m
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %% [markdown]
# # Gradient Descent

# %%
# Lets apply Gradient Descent assuming slope is constant m = 78.35
# and let's assume the starting value for intercept b = 0
y_pred = ((78.35 * X) + 0).reshape(4)
y_pred
# Out:
# array([-55.81580837,  35.39949674,  -3.48681619,  59.05759577])

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#00a65a',label='b = 0')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -209.27763408209216

# %%
# Lets take learning rate = 0.1
lr = 0.1

step_size = loss_slope*lr
step_size
# Out:
# -20.927763408209216

# %%
# Calculating the new intercept
b = b - step_size
b
# Out:
# 20.927763408209216

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 2
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -41.85552681641843

# %%
step_size = loss_slope*lr
step_size
# Out:
# -4.185552681641844

# %%
b = b - step_size
b
# Out:
# 25.11331608985106

# %%
y_pred2 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred2,color='#00a65a',linestyle=':',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='#A3E4D7',label='b =40.9277634')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -8.371105363283675

# %%
step_size = loss_slope*lr
step_size
# Out:
# -0.8371105363283675

# %%
b = b - step_size
b
# Out:
# 25.95042662617943

# %%
y_pred3 = ((78.35 * X) + b).reshape(4)

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred3,linestyle='--',color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred2,color='#A3E4D7',label='b = pred2')
plt.plot(X,y_pred1,color='#A3E4D7',label='b = pred 1')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -1.674221072656735

# %%
step_size = loss_slope*lr
step_size
# Out:
# -0.16742210726567353

# %%
b = b - step_size
b
# Out:
# 26.1178487334451

# %%
y_pred4 = ((78.35 * X) + b).reshape(4)

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred4,linestyle=':',color='cyan',label='b = {}'.format(b))

# plt.plot(X,y_pred3,color='k',label='b = pred 3')
# plt.plot(X,y_pred2,color='#A3E4D7',label='b = pred2')
# plt.plot(X,y_pred1,color='#A3E4D7',label='b = pred 1')
# plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -0.3348442145313584

# %%
step_size = loss_slope*lr
step_size
# Out:
# -0.03348442145313584

# %%
b = b - step_size
b
# Out:
# 26.151333154898236

# %%
y_pred5 = ((78.35 * X) + b).reshape(4)

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred5,linestyle='--',color='#00a65a',label='b = {}'.format(b))

plt.plot(X,y_pred4,linestyle='--',color='#00a65a',label='26.18')

plt.plot(X,y_pred3,color='k',label='b = pred 3')
plt.plot(X,y_pred2,color='#A3E4D7',label='b = pred2')
plt.plot(X,y_pred1,color='#A3E4D7',label='b = pred 1')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# Iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -0.3348442145313584

# %%
step_size = loss_slope*lr
step_size
# Out:
# -0.03348442145313584

# %%
b = b - step_size
b
# Out:
# 26.151333154898236

# %%
y_pred6 = ((78.35 * X) + b).reshape(4)

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred6,linestyle='-',color='#00a65a',label='b = {}'.format(b))

plt.plot(X,y_pred4,linestyle='--',color='#00a65a',label='26.18')

plt.plot(X,y_pred3,color='k',label='b = pred 3')
plt.plot(X,y_pred2,color='#A3E4D7',label='b = pred2')
plt.plot(X,y_pred1,color='#A3E4D7',label='b = pred 1')
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# -0.01339376858126684

# %%
step_size = loss_slope*lr
step_size
# Out:
# -0.001339376858126684

# %%
b = b - step_size
b
# Out:
# 26.15936941604699

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
26.15936941604699-26.15969086649294
# Out:
# -0.0003214504459521095

# %%
b = 200
m = 78.35
lr = 0.1

epochs = 100

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b)
    b = b - (lr * loss_slope)

    y_pred = m * X + b
    print(b)
    

    plt.plot(X,y_pred)
    plt.plot(X,reg.predict(X),color='k',label='OLS')
# plt.legend()


# plt.scatter(X,y)
# Out:
# 60.927763408209245
# 33.11331608985107
# 27.55042662617943
# 26.4378487334451
# 26.215333154898236
# 26.170830039188864
# 26.161929416046988
# 26.160149291418612
# 26.15979326649294
# 26.159722061507804
# 26.15970782051078
# 26.15970497231137
# 26.15970440267149
# 26.159704288743516
# 26.15970426595792
# 26.1597042614008
# 26.159704260489377
# 26.15970426030709
# 26.159704260270633
# 26.159704260263343
# 26.159704260261886
# 26.159704260261595
# 26.159704260261535
# 26.159704260261524
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# 26.15970426026152
# ...
