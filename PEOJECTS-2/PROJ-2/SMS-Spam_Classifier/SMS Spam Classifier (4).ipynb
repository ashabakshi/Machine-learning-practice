# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Book1 (3).csv')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# # 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# df[~(df['Unnamed: 2'].isnull())]

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# v1             0.000000
# v2             0.000000
# Unnamed: 2    99.102656
# Unnamed: 3    99.784637
# Unnamed: 4    99.892319
# dtype: float64

# %%
# dropping last 3 columns
df=df.iloc[:,0:2]
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
5572-403
# Out:
# 5169

# %%
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['target']=le.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 403

# %%
# remove duplicates
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # 2. EDA (Exploratory Data Analysis)

# %%
# How may Spam and not spam sms are their
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct='%0.2f%%')
plt.show()

# %% [markdown]
# **data is imbalanced**

# %%
# ! pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cipl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# counting the number of characters in an email
df['num_characters']=df['text'].apply(len)

# %%
# df.head()

# %%
# num of words
df['num_words']=df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
# number of sentences
df['num_sentences']=df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# 3                 49         13              1
# 4                 61         15              1
# ...              ...        ...            ...
# 5567             161         35              4
# 5568              37          9              1
# 5569              57         15              2
# 5570             125         27              1
# 5571              26          7              2
#
# [5169 rows x 5 columns]

# %%
df.iloc[:,2:].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# ham messages
df[df['target']==0].iloc[:,2:].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# spam messages
df[df['target']==1].iloc[:,2:].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,5.5))
plt.title('No of character in spam and not spam SMS')
sns.histplot(df[df['target']==0].iloc[:,2],label='not spam')
sns.histplot(df[df['target']==1].iloc[:,2],color='red',label='spam')
plt.legend()
plt.show()

# %% [markdown]
# **aapke jo not spam messages hai usmein jo characters use ho rhe h woh zaadaa hai**

# %% [markdown]
#  **where as aapke jo spam messages has usmein characters thode kamm hai**

# %%
plt.figure(figsize=(10,5.5))
plt.title('No of words in spam and not spam SMS')
sns.histplot(df[df['target']==0].iloc[:,3],label='not spam')
sns.histplot(df[df['target']==1].iloc[:,3],color='red',label='spam')
plt.legend()
plt.show()

# %% [markdown]
# **mostly  spam messages kam word se millkar bnte hai**

# %% [markdown]
# **and not spam messages zaadaaa words se millkar bnte hai**

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# 3                 49         13              1
# 4                 61         15              1
# ...              ...        ...            ...
# 5567             161         35              4
# 5568              37          9              1
# 5569              57         15              2
# 5570             125         27              1
# 5571              26          7              2
#
# [5169 rows x 5 columns]

# %%
num_rows=df.select_dtypes(include=np.number)
num_rows
# Out:
#       target  num_characters  num_words  num_sentences
# 0          0             111         24              2
# 1          0              29          8              2
# 2          1             155         37              2
# 3          0              49         13              1
# 4          0              61         15              1
# ...      ...             ...        ...            ...
# 5567       1             161         35              4
# 5568       0              37          9              1
# 5569       0              57         15              2
# 5570       0             125         27              1
# 5571       0              26          7              2
#
# [5169 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(num_rows.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Apna target jo hai num_character pr 0.38 ka correlation hai**

# %% [markdown]
# **mean jitne zaaadaa aapke character badhte hai toh 1 hone ka tendency bhi badhta hai mean spam**

# %% [markdown]
# **after looking this heatmap isee that here is a high multicollinearity so i will select only 1 column**

# %% [markdown]
# # Data Preprocessing
# - Lower Case
# - Tokenization
# - Removing Special Characters
# - Removing Stop words & punctuations
# - Stemming

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('joinning')
# Out:
# 'join'

# %%
def transform_text(text):
    text=text.lower()# converting in lower case
    print(text)
    text=nltk.word_tokenize(text)# splitting into words
    print(text)
    # removing special characters
    L=[]
    for i in text:
        if i.isalnum():
            L.append(i)
    print(L)
    
# #     # removing stop words and punctuation marks
    text=L.copy()
    L.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            L.append(i)
    print(L)
# # #     # applying stemming
    text=L.copy()
    L.clear()
    for i in text:
        L.append(ps.stem(i))
    print(L)
        
    return " ".join(L)

# %%
transform_text('helLo i am WALKING ? Are you ^ joinning me.')
# Out:
# hello i am walking ? are you ^ joinning me.
# ['hello', 'i', 'am', 'walking', '?', 'are', 'you', '^', 'joinning', 'me', '.']
# ['hello', 'i', 'am', 'walking', 'are', 'you', 'joinning', 'me']
# ['hello', 'walking', 'joinning']
# ['hello', 'walk', 'join']
# 'hello walk join'

# %%
transform_text('i am enjoying this FDP on Machine Learning ? How about you.')
# Out:
# ['i', 'am', 'enjoying', 'this', 'fdp', 'on', 'machine', 'learning', '?', 'how', 'about', 'you', '.']
# ['i', 'am', 'enjoying', 'this', 'fdp', 'on', 'machine', 'learning', 'how', 'about', 'you']
# ['enjoying', 'fdp', 'machine', 'learning']
# 'enjoy fdp machin learn'

# %%
# testing the function
transform_text(df['text'][10])
# Out:
# ['i', "'m", 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'do', "n't", 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', ',', 'k', '?', 'i', "'ve", 'cried', 'enough', 'today', '.']
# ['i', 'gon', 'na', 'be', 'home', 'soon', 'and', 'i', 'do', 'want', 'to', 'talk', 'about', 'this', 'stuff', 'anymore', 'tonight', 'k', 'i', 'cried', 'enough', 'today']
# ['gon', 'na', 'home', 'soon', 'want', 'talk', 'stuff', 'anymore', 'tonight', 'k', 'cried', 'enough', 'today']
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['transformed_text']=df['text'].apply(transform_text)
# Out:
# ['yup', 'need', 'jus', 'wait', '4', 'e', 'rain', '2', 'stop']
# ['there', 'are', 'many', 'company', '.', 'tell', 'me', 'the', 'language', '.']
# ['there', 'are', 'many', 'company', 'tell', 'me', 'the', 'language']
# ['many', 'company', 'tell', 'language']
# ['okmail', ':', 'dear', 'dave', 'this', 'is', 'your', 'final', 'notice', 'to', 'collect', 'your', '4', '*', 'tenerife', 'holiday', 'or', '#', '5000', 'cash', 'award', '!', 'call', '09061743806', 'from', 'landline', '.', 'tcs', 'sae', 'box326', 'cw25wx', '150ppm']
# ['okmail', 'dear', 'dave', 'this', 'is', 'your', 'final', 'notice', 'to', 'collect', 'your', '4', 'tenerife', 'holiday', 'or', '5000', 'cash', 'award', 'call', '09061743806', 'from', 'landline', 'tcs', 'sae', 'box326', 'cw25wx', '150ppm']
# ['okmail', 'dear', 'dave', 'final', 'notice', 'collect', '4', 'tenerife', 'holiday', '5000', 'cash', 'award', 'call', '09061743806', 'landline', 'tcs', 'sae', 'box326', 'cw25wx', '150ppm']
# ['how', 'long', 'has', 'it', 'been', 'since', 'you', 'screamed', ',', 'princess', '?']
# ['how', 'long', 'has', 'it', 'been', 'since', 'you', 'screamed', 'princess']
# ['long', 'since', 'screamed', 'princess']
# ['nothing', '.', 'i', 'meant', 'that', 'once', 'the', 'money', 'enters', 'your', 'account', 'here', ',', 'the', 'bank', 'will', 'remove', 'its', 'flat', 'rate', '.', 'someone', 'transfered', '&', 'lt', ';', '#', '&', 'gt', ';', 'to', 'my', 'account', 'and', '&', 'lt', ';', '#', '&', 'gt', ';', 'dollars', 'got', 'removed', '.', 'so', 'the', 'banks', 'differ', 'and', 'charges', 'also', 'differ.be', 'sure', 'you', 'trust', 'the', '9ja', 'person', 'you', 'are', 'sending', 'account', 'details', 'to', 'cos', '...']
# ['nothing', 'i', 'meant', 'that', 'once', 'the', 'money', 'enters', 'your', 'account', 'here', 'the', 'bank', 'will', 'remove', 'its', 'flat', 'rate', 'someone', 'transfered', 'lt', 'gt', 'to', 'my', 'account', 'and', 'lt', 'gt', 'dollars', 'got', 'removed', 'so', 'the', 'banks', 'differ', 'and', 'charges', 'also', 'sure', 'you', 'trust', 'the', '9ja', 'person', 'you', 'are', 'sending', 'account', 'details', 'to', 'cos']
# ['nothing', 'meant', 'money', 'enters', 'account', 'bank', 'remove', 'flat', 'rate', 'someone', 'transfered', 'lt', 'gt', 'account', 'lt', 'gt', 'dollars', 'got', 'removed', 'banks', 'differ', 'charges', 'also', 'sure', 'trust', '9ja', 'person', 'sending', 'account', 'details', 'cos']
# ['want', '2', 'get', 'laid', 'tonight', '?', 'want', 'real', 'dogging', 'locations', 'sent', 'direct', '2', 'ur', 'mob', '?', 'join', 'the', 'uk', "'s", 'largest', 'dogging', 'network', 'by', 'txting', 'moan', 'to', '69888nyt', '.', 'ec2a', '.', '31p.msg', '@', '150p']
# ['want', '2', 'get', 'laid', 'tonight', 'want', 'real', 'dogging', 'locations', 'sent', 'direct', '2', 'ur', 'mob', 'join', 'the', 'uk', 'largest', 'dogging', 'network', 'by', 'txting', 'moan', 'to', '69888nyt', 'ec2a', '150p']
# ['want', '2', 'get', 'laid', 'tonight', 'want', 'real', 'dogging', 'locations', 'sent', 'direct', '2', 'ur', 'mob', 'join', 'uk', 'largest', 'dogging', 'network', 'txting', 'moan', '69888nyt', 'ec2a', '150p']
# ['nice', 'line', 'said', 'by', 'a', 'broken', 'heart-', 'plz', 'do', "n't", 'cum', '1', 'more', 'times', 'infront', 'of', 'me', '...', 'other', 'wise', 'once', 'again', 'i', 'll', 'trust', 'u', '...', 'good', '9t', ':', ')']
# ['nice', 'line', 'said', 'by', 'a', 'broken', 'plz', 'do', 'cum', '1', 'more', 'times', 'infront', 'of', 'me', 'other', 'wise', 'once', 'again', 'i', 'll', 'trust', 'u', 'good', '9t']
# ['nice', 'line', 'said', 'broken', 'plz', 'cum', '1', 'times', 'infront', 'wise', 'trust', 'u', 'good', '9t']
# ['ok', 'i', "'m", 'gon', 'na', 'head', 'up', 'to', 'usf', 'in', 'like', 'fifteen', 'minutes']
# ['ok', 'i', 'gon', 'na', 'head', 'up', 'to', 'usf', 'in', 'like', 'fifteen', 'minutes']
# ['ok', 'gon', 'na', 'head', 'usf', 'like', 'fifteen', 'minutes']
# ['love', 'you', 'aathi', '..', 'love', 'u', 'lot', '..']
# ['love', 'you', 'aathi', 'love', 'u', 'lot']
# ['love', 'aathi', 'love', 'u', 'lot']
# ['tension', 'ah', '?', 'what', 'machi', '?', 'any', 'problem', '?']
# ['tension', 'ah', 'what', 'machi', 'any', 'problem']
# ['tension', 'ah', 'machi', 'problem']
# ['k', ',', 'can', 'i', 'pick', 'up', 'another', '8th', 'when', 'you', "'re", 'done', '?']
# ['k', 'can', 'i', 'pick', 'up', 'another', '8th', 'when', 'you', 'done']
# ['k', 'pick', 'another', '8th', 'done']
# ['when', "'re", 'you', 'guys', 'getting', 'back', '?', 'g', 'said', 'you', 'were', 'thinking', 'about', 'not', 'staying', 'for', 'mcr']
# ['when', 'you', 'guys', 'getting', 'back', 'g', 'said', 'you', 'were', 'thinking', 'about', 'not', 'staying', 'for', 'mcr']
# ['guys', 'getting', 'back', 'g', 'said', 'thinking', 'staying', 'mcr']
# ['almost', 'there', ',', 'see', 'u', 'in', 'a', 'sec']
# ['almost', 'there', 'see', 'u', 'in', 'a', 'sec']
# ['almost', 'see', 'u', 'sec']
# ['yo', 'carlos', ',', 'a', 'few', 'friends', 'are', 'already', 'asking', 'me', 'about', 'you', ',', 'you', 'working', 'at', 'all', 'this', 'weekend', '?']
# ['yo', 'carlos', 'a', 'few', 'friends', 'are', 'already', 'asking', 'me', 'about', 'you', 'you', 'working', 'at', 'all', 'this', 'weekend']
# ['yo', 'carlos', 'friends', 'already', 'asking', 'working', 'weekend']
# ['watching', 'tv', 'lor', '...']
# ['watching', 'tv', 'lor']
# ['watching', 'tv', 'lor']
# ['thank', 'you', 'baby', '!', 'i', 'cant', 'wait', 'to', 'taste', 'the', 'real', 'thing', '...']
# ['thank', 'you', 'baby', 'i', 'cant', 'wait', 'to', 'taste', 'the', 'real', 'thing']
# ['thank', 'baby', 'cant', 'wait', 'taste', 'real', 'thing']
# ['you', 'should', 'change', 'your', 'fb', 'to', 'jaykwon', 'thuglyfe', 'falconerf']
# ['you', 'should', 'change', 'your', 'fb', 'to', 'jaykwon', 'thuglyfe', 'falconerf']
# ['change', 'fb', 'jaykwon', 'thuglyfe', 'falconerf']
# ['if', 'we', 'win', 'its', 'really', 'no', '1', 'side', 'for', 'long', 'time', '.']
# ['if', 'we', 'win', 'its', 'really', 'no', '1', 'side', 'for', 'long', 'time']
# ['win', 'really', '1', 'side', 'long', 'time']
# ['free', 'message', 'activate', 'your', '500', 'free', 'text', 'messages', 'by', 'replying', 'to', 'this', 'message', 'with', 'the', 'word', 'free', 'for', 'terms', '&', 'conditions', ',', 'visit', 'www.07781482378.com']
# ['free', 'message', 'activate', 'your', '500', 'free', 'text', 'messages', 'by', 'replying', 'to', 'this', 'message', 'with', 'the', 'word', 'free', 'for', 'terms', 'conditions', 'visit']
# ['free', 'message', 'activate', '500', 'free', 'text', 'messages', 'replying', 'message', 'word', 'free', 'terms', 'conditions', 'visit']
# ['dear', 'reached', 'railway', '.', 'what', 'happen', 'to', 'you']
# ['dear', 'reached', 'railway', 'what', 'happen', 'to', 'you']
# ['dear', 'reached', 'railway', 'happen']
# ['depends', 'on', 'quality', '.', 'if', 'you', 'want', 'the', 'type', 'i', 'sent', 'boye', ',', 'faded', 'glory', ',', 'then', 'about', '6.', 'if', 'you', 'want', 'ralphs', 'maybe', '2']
# ['depends', 'on', 'quality', 'if', 'you', 'want', 'the', 'type', 'i', 'sent', 'boye', 'faded', 'glory', 'then', 'about', 'if', 'you', 'want', 'ralphs', 'maybe', '2']
# ['depends', 'quality', 'want', 'type', 'sent', 'boye', 'faded', 'glory', 'want', 'ralphs', 'maybe', '2']
# ['i', 'think', 'i', "'ve", 'fixed', 'it', 'can', 'you', 'send', 'a', 'test', 'message', '?']
# ['i', 'think', 'i', 'fixed', 'it', 'can', 'you', 'send', 'a', 'test', 'message']
# ['think', 'fixed', 'send', 'test', 'message']
# ['sorry', 'man', 'my', 'account', "'s", 'dry', 'or', 'i', 'would', ',', 'if', 'you', 'want', 'we', 'could', 'trade', 'back', 'half', 'or', 'i', 'could', 'buy', 'some', 'shit', 'with', 'my', 'credit', 'card']
# ['sorry', 'man', 'my', 'account', 'dry', 'or', 'i', 'would', 'if', 'you', 'want', 'we', 'could', 'trade', 'back', 'half', 'or', 'i', 'could', 'buy', 'some', 'shit', 'with', 'my', 'credit', 'card']
# ['sorry', 'man', 'account', 'dry', 'would', 'want', 'could', 'trade', 'back', 'half', 'could', 'buy', 'shit', 'credit', 'card']
# ['congrats', '!', '1', 'year', 'special', 'cinema', 'pass', 'for', '2', 'is', 'yours', '.', 'call', '09061209465', 'now', '!', 'c', 'suprman', 'v', ',', 'matrix3', ',', 'starwars3', ',', 'etc', 'all', '4', 'free', '!', 'bx420-ip4-5we', '.', '150pm', '.', 'dont', 'miss', 'out', '!']
# ['congrats', '1', 'year', 'special', 'cinema', 'pass', 'for', '2', 'is', 'yours', 'call', '09061209465', 'now', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', 'all', '4', 'free', '150pm', 'dont', 'miss', 'out']
# ['congrats', '1', 'year', 'special', 'cinema', 'pass', '2', 'call', '09061209465', 'c', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', '4', 'free', '150pm', 'dont', 'miss']
# ['sorry', ',', 'in', 'meeting', 'i', "'ll", 'call', 'later']
# ['sorry', 'in', 'meeting', 'i', 'call', 'later']
# ['sorry', 'meeting', 'call', 'later']
# ['what', 'class', 'of', '&', 'lt', ';', '#', '&', 'gt', ';', 'reunion', '?']
# ['what', 'class', 'of', 'lt', 'gt', 'reunion']
# ['class', 'lt', 'gt', 'reunion']
# ['are', 'you', 'free', 'now', '?', 'can', 'i', 'call', 'now', '?']
# ['are', 'you', 'free', 'now', 'can', 'i', 'call', 'now']
# ['free', 'call']
# ['got', 'meh', '...', 'when', '?']
# ['got', 'meh', 'when']
# ['got', 'meh']
# ['nope', '...', 'think', 'i', 'will', 'go', 'for', 'it', 'on', 'monday', '...', 'sorry', 'i', 'replied', 'so', 'late']
# ['nope', 'think', 'i', 'will', 'go', 'for', 'it', 'on', 'monday', 'sorry', 'i', 'replied', 'so', 'late']
# ['nope', 'think', 'go', 'monday', 'sorry', 'replied', 'late']
# ['some', 'of', 'them', 'told', 'accenture', 'is', 'not', 'confirm', '.', 'is', 'it', 'true', '.']
# ['some', 'of', 'them', 'told', 'accenture', 'is', 'not', 'confirm', 'is', 'it', 'true']
# ['told', 'accenture', 'confirm', 'true']
# ['kate', 'jackson', 'rec', 'center', 'before', '7ish', ',', 'right', '?']
# ['kate', 'jackson', 'rec', 'center', 'before', '7ish', 'right']
# ['kate', 'jackson', 'rec', 'center', '7ish', 'right']
# ['dear', 'i', 'have', 'reache', 'room']
# ['dear', 'i', 'have', 'reache', 'room']
# ['dear', 'reache', 'room']
# ['fighting', 'with', 'the', 'world', 'is', 'easy', ',', 'u', 'either', 'win', 'or', 'lose', 'bt', 'fightng', 'with', 'some1', 'who', 'is', 'close', 'to', 'u', 'is', 'dificult', 'if', 'u', 'lose', '-', 'u', 'lose', 'if', 'u', 'win', '-', 'u', 'still', 'lose', '.']
# ['fighting', 'with', 'the', 'world', 'is', 'easy', 'u', 'either', 'win', 'or', 'lose', 'bt', 'fightng', 'with', 'some1', 'who', 'is', 'close', 'to', 'u', 'is', 'dificult', 'if', 'u', 'lose', 'u', 'lose', 'if', 'u', 'win', 'u', 'still', 'lose']
# ['fighting', 'world', 'easy', 'u', 'either', 'win', 'lose', 'bt', 'fightng', 'some1', 'close', 'u', 'dificult', 'u', 'lose', 'u', 'lose', 'u', 'win', 'u', 'still', 'lose']
# ['when', 'can', 'ì_', 'come', 'out', '?']
# ['when', 'can', 'come', 'out']
# ['come']
# ['check', 'with', 'nuerologist', '.']
# ['check', 'with', 'nuerologist']
# ['check', 'nuerologist']
# ['lolnice', '.', 'i', 'went', 'from', 'a', 'fish', 'to', '..', 'water', '.', '?']
# ['lolnice', 'i', 'went', 'from', 'a', 'fish', 'to', 'water']
# ['lolnice', 'went', 'fish', 'water']
# ['+123', 'congratulations', '-', 'in', 'this', 'week', "'s", 'competition', 'draw', 'u', 'have', 'won', 'the', 'å£1450', 'prize', 'to', 'claim', 'just', 'call', '09050002311', 'b4280703', '.', 't', '&', 'cs/stop', 'sms', '08718727868.', 'over', '18', 'only', '150ppm']
# ['congratulations', 'in', 'this', 'week', 'competition', 'draw', 'u', 'have', 'won', 'the', 'prize', 'to', 'claim', 'just', 'call', '09050002311', 'b4280703', 't', 'sms', 'over', '18', 'only', '150ppm']
# ['congratulations', 'week', 'competition', 'draw', 'u', 'prize', 'claim', 'call', '09050002311', 'b4280703', 'sms', '18', '150ppm']
# ['no', 'it', "'s", 'waiting', 'in', 'e', 'car', 'dat', "'s", 'bored', 'wat', '.', 'cos', 'wait', 'outside', 'got', 'nothing', '2', 'do', '.', 'at', 'home', 'can', 'do', 'my', 'stuff', 'or', 'watch', 'tv', 'wat', '.']
# ['no', 'it', 'waiting', 'in', 'e', 'car', 'dat', 'bored', 'wat', 'cos', 'wait', 'outside', 'got', 'nothing', '2', 'do', 'at', 'home', 'can', 'do', 'my', 'stuff', 'or', 'watch', 'tv', 'wat']
# ['waiting', 'e', 'car', 'dat', 'bored', 'wat', 'cos', 'wait', 'outside', 'got', 'nothing', '2', 'home', 'stuff', 'watch', 'tv', 'wat']
# ['maybe', 'westshore', 'or', 'hyde', 'park', 'village', ',', 'the', 'place', 'near', 'my', 'house', '?']
# ['maybe', 'westshore', 'or', 'hyde', 'park', 'village', 'the', 'place', 'near', 'my', 'house']
# ['maybe', 'westshore', 'hyde', 'park', 'village', 'place', 'near', 'house']
# ['you', 'should', 'know', 'now', '.', 'so', 'how', "'s", 'anthony', '.', 'are', 'you', 'bringing', 'money', '.', 'i', "'ve", 'school', 'fees', 'to', 'pay', 'and', 'rent', 'and', 'stuff', 'like', 'that', '.', 'thats', 'why', 'i', 'need', 'your', 'help', '.', 'a', 'friend', 'in', 'need', '....', '|']
# ['you', 'should', 'know', 'now', 'so', 'how', 'anthony', 'are', 'you', 'bringing', 'money', 'i', 'school', 'fees', 'to', 'pay', 'and', 'rent', 'and', 'stuff', 'like', 'that', 'thats', 'why', 'i', 'need', 'your', 'help', 'a', 'friend', 'in', 'need']
# ['know', 'anthony', 'bringing', 'money', 'school', 'fees', 'pay', 'rent', 'stuff', 'like', 'thats', 'need', 'help', 'friend', 'need']
# ['what', "'s", 'the', 'significance', '?']
# ['what', 'the', 'significance']
# ['significance']
# ['your', 'opinion', 'about', 'me', '?', '1.', 'over', '2.', 'jada', '3.', 'kusruthi', '4.', 'lovable', '5.', 'silent', '6.', 'spl', 'character', '7.', 'not', 'matured', '8.', 'stylish', '9.', 'simple', 'pls', 'reply', '..']
# ['your', 'opinion', 'about', 'me', 'over', 'jada', 'kusruthi', 'lovable', 'silent', 'spl', 'character', 'not', 'matured', 'stylish', 'simple', 'pls', 'reply']
# ['opinion', 'jada', 'kusruthi', 'lovable', 'silent', 'spl', 'character', 'matured', 'stylish', 'simple', 'pls', 'reply']
# ['8', 'at', 'the', 'latest', ',', 'g', "'s", 'still', 'there', 'if', 'you', 'can', 'scrounge', 'up', 'some', 'ammo', 'and', 'want', 'to', 'give', 'the', 'new', 'ak', 'a', 'try']
# ['8', 'at', 'the', 'latest', 'g', 'still', 'there', 'if', 'you', 'can', 'scrounge', 'up', 'some', 'ammo', 'and', 'want', 'to', 'give', 'the', 'new', 'ak', 'a', 'try']
# ['8', 'latest', 'g', 'still', 'scrounge', 'ammo', 'want', 'give', 'new', 'ak', 'try']
# ['prabha', '..', 'i', "'m", 'soryda', '..', 'realy', '..', 'frm', 'heart', 'i', "'m", 'sory']
# ['prabha', 'i', 'soryda', 'realy', 'frm', 'heart', 'i', 'sory']
# ['prabha', 'soryda', 'realy', 'frm', 'heart', 'sory']
# ['lol', 'ok', 'your', 'forgiven', ':', ')']
# ['lol', 'ok', 'your', 'forgiven']
# ['lol', 'ok', 'forgiven']
# ['no', '..', 'jst', 'change', 'tat', 'only', '..']
# ['no', 'jst', 'change', 'tat', 'only']
# ['jst', 'change', 'tat']
# ['you', 'are', 'guaranteed', 'the', 'latest', 'nokia', 'phone', ',', 'a', '40gb', 'ipod', 'mp3', 'player', 'or', 'a', 'å£500', 'prize', '!', 'txt', 'word', ':', 'collect', 'to', 'no', ':', '83355', '!', 'ibhltd', 'ldnw15h', '150p/mtmsgrcvd18+']
# ['you', 'are', 'guaranteed', 'the', 'latest', 'nokia', 'phone', 'a', '40gb', 'ipod', 'mp3', 'player', 'or', 'a', 'prize', 'txt', 'word', 'collect', 'to', 'no', '83355', 'ibhltd', 'ldnw15h']
# ['guaranteed', 'latest', 'nokia', 'phone', '40gb', 'ipod', 'mp3', 'player', 'prize', 'txt', 'word', 'collect', '83355', 'ibhltd', 'ldnw15h']
# ['s', ':', ')', 'no', 'competition', 'for', 'him', '.']
# ['s', 'no', 'competition', 'for', 'him']
# ['competition']
# ['boltblue', 'tones', 'for', '150p', 'reply', 'poly', '#', 'or', 'mono', '#', 'eg', 'poly3', '1.', 'cha', 'cha', 'slide', '2.', 'yeah', '3.', 'slow', 'jamz', '6.', 'toxic', '8.', 'come', 'with', 'me', 'or', 'stop', '4', 'more', 'tones', 'txt', 'more']
# ['boltblue', 'tones', 'for', '150p', 'reply', 'poly', 'or', 'mono', 'eg', 'poly3', 'cha', 'cha', 'slide', 'yeah', 'slow', 'jamz', 'toxic', 'come', 'with', 'me', 'or', 'stop', '4', 'more', 'tones', 'txt', 'more']
# ['boltblue', 'tones', '150p', 'reply', 'poly', 'mono', 'eg', 'poly3', 'cha', 'cha', 'slide', 'yeah', 'slow', 'jamz', 'toxic', 'come', 'stop', '4', 'tones', 'txt']
# ['your', 'credits', 'have', 'been', 'topped', 'up', 'for', 'http', ':', '//www.bubbletext.com', 'your', 'renewal', 'pin', 'is', 'tgxxrz']
# ['your', 'credits', 'have', 'been', 'topped', 'up', 'for', 'http', 'your', 'renewal', 'pin', 'is', 'tgxxrz']
# ['credits', 'topped', 'http', 'renewal', 'pin', 'tgxxrz']
# ['that', 'way', 'transport', 'is', 'less', 'problematic', 'than', 'on', 'sat', 'night', '.', 'by', 'the', 'way', ',', 'if', 'u', 'want', 'to', 'ask', 'n', 'to', 'join', 'my', 'bday', ',', 'feel', 'free', '.', 'but', 'need', 'to', 'know', 'definite', 'nos', 'as', 'booking', 'on', 'fri', '.']
# ['that', 'way', 'transport', 'is', 'less', 'problematic', 'than', 'on', 'sat', 'night', 'by', 'the', 'way', 'if', 'u', 'want', 'to', 'ask', 'n', 'to', 'join', 'my', 'bday', 'feel', 'free', 'but', 'need', 'to', 'know', 'definite', 'nos', 'as', 'booking', 'on', 'fri']
# ['way', 'transport', 'less', 'problematic', 'sat', 'night', 'way', 'u', 'want', 'ask', 'n', 'join', 'bday', 'feel', 'free', 'need', 'know', 'definite', 'nos', 'booking', 'fri']
# ['usually', 'the', 'person', 'is', 'unconscious', 'that', "'s", 'in', 'children', 'but', 'in', 'adults', 'they', 'may', 'just', 'behave', 'abnormally', '.', 'i.ll', 'call', 'you', 'now']
# ['usually', 'the', 'person', 'is', 'unconscious', 'that', 'in', 'children', 'but', 'in', 'adults', 'they', 'may', 'just', 'behave', 'abnormally', 'call', 'you', 'now']
# ['usually', 'person', 'unconscious', 'children', 'adults', 'may', 'behave', 'abnormally', 'call']
# ['but', 'that', "'s", 'on', 'ebay', 'it', 'might', 'be', 'less', 'elsewhere', '.']
# ['but', 'that', 'on', 'ebay', 'it', 'might', 'be', 'less', 'elsewhere']
# ['ebay', 'might', 'less', 'elsewhere']
# ['shall', 'i', 'come', 'to', 'get', 'pickle']
# ['shall', 'i', 'come', 'to', 'get', 'pickle']
# ['shall', 'come', 'get', 'pickle']
# ['were', 'gon', 'na', 'go', 'get', 'some', 'tacos']
# ['were', 'gon', 'na', 'go', 'get', 'some', 'tacos']
# ['gon', 'na', 'go', 'get', 'tacos']
# ['that', "'s", 'very', 'rude', ',', 'you', 'on', 'campus', '?']
# ['that', 'very', 'rude', 'you', 'on', 'campus']
# ['rude', 'campus']
# ['urgent', '!', ':', 'your', 'mobile', 'no', '.', 'was', 'awarded', 'a', 'å£2,000', 'bonus', 'caller', 'prize', 'on', '02/09/03', '!', 'this', 'is', 'our', '2nd', 'attempt', 'to', 'contact', 'you', '!', 'call', '0871-872-9755', 'box95qu']
# ['urgent', 'your', 'mobile', 'no', 'was', 'awarded', 'a', 'bonus', 'caller', 'prize', 'on', 'this', 'is', 'our', '2nd', 'attempt', 'to', 'contact', 'you', 'call', 'box95qu']
# ['urgent', 'mobile', 'awarded', 'bonus', 'caller', 'prize', '2nd', 'attempt', 'contact', 'call', 'box95qu']
# ['hi', 'i', 'wo', "n't", 'b', 'ard', '4', 'christmas', '.', 'but', 'do', 'enjoy', 'n', 'merry', "x'mas", '.']
# ['hi', 'i', 'wo', 'b', 'ard', '4', 'christmas', 'but', 'do', 'enjoy', 'n', 'merry']
# ['hi', 'wo', 'b', 'ard', '4', 'christmas', 'enjoy', 'n', 'merry']
# ['today', "'s", 'offer', '!', 'claim', 'ur', 'å£150', 'worth', 'of', 'discount', 'vouchers', '!', 'text', 'yes', 'to', '85023', 'now', '!', 'savamob', ',', 'member', 'offers', 'mobile', '!', 't', 'cs', '08717898035.', 'å£3.00', 'sub', '.', '16', '.', 'unsub', 'reply', 'x']
# ['today', 'offer', 'claim', 'ur', 'worth', 'of', 'discount', 'vouchers', 'text', 'yes', 'to', '85023', 'now', 'savamob', 'member', 'offers', 'mobile', 't', 'cs', 'sub', '16', 'unsub', 'reply', 'x']
# ['today', 'offer', 'claim', 'ur', 'worth', 'discount', 'vouchers', 'text', 'yes', '85023', 'savamob', 'member', 'offers', 'mobile', 'cs', 'sub', '16', 'unsub', 'reply', 'x']
# ['yes', '!', 'how', 'is', 'a', 'pretty', 'lady', 'like', 'you', 'single', '?']
# ['yes', 'how', 'is', 'a', 'pretty', 'lady', 'like', 'you', 'single']
# ['yes', 'pretty', 'lady', 'like', 'single']
# ['you', 'will', 'recieve', 'your', 'tone', 'within', 'the', 'next', '24hrs', '.', 'for', 'terms', 'and', 'conditions', 'please', 'see', 'channel', 'u', 'teletext', 'pg', '750']
# ['you', 'will', 'recieve', 'your', 'tone', 'within', 'the', 'next', '24hrs', 'for', 'terms', 'and', 'conditions', 'please', 'see', 'channel', 'u', 'teletext', 'pg', '750']
# ['recieve', 'tone', 'within', 'next', '24hrs', 'terms', 'conditions', 'please', 'see', 'channel', 'u', 'teletext', 'pg', '750']
# ['jay', 'says', 'that', 'you', "'re", 'a', 'double-faggot']
# ['jay', 'says', 'that', 'you', 'a']
# ['jay', 'says']
# ['private', '!', 'your', '2003', 'account', 'statement', 'for', '07815296484', 'shows', '800', 'un-redeemed', 's.i.m', '.', 'points', '.', 'call', '08718738001', 'identifier', 'code', '41782', 'expires', '18/11/04']
# ['private', 'your', '2003', 'account', 'statement', 'for', '07815296484', 'shows', '800', 'points', 'call', '08718738001', 'identifier', 'code', '41782', 'expires']
# ['private', '2003', 'account', 'statement', '07815296484', 'shows', '800', 'points', 'call', '08718738001', 'identifier', 'code', '41782', 'expires']
# ['what', 'today-sunday', '..', 'sunday', 'is', 'holiday', '..', 'so', 'no', 'work', '..']
# ['what', 'sunday', 'is', 'holiday', 'so', 'no', 'work']
# ['sunday', 'holiday', 'work']
# ['i', "'ll", 'be', 'late', '...']
# ['i', 'be', 'late']
# ['late']
# ['i', "'ve", 'not', 'called', 'you', 'in', 'a', 'while', '.', 'this', 'is', 'hoping', 'it', 'was', 'l8r', 'malaria', 'and', 'that', 'you', 'know', 'that', 'we', 'miss', 'you', 'guys', '.', 'i', 'miss', 'bani', 'big', ',', 'so', 'pls', 'give', 'her', 'my', 'love', 'especially', '.', 'have', 'a', 'great', 'day', '.']
# ['i', 'not', 'called', 'you', 'in', 'a', 'while', 'this', 'is', 'hoping', 'it', 'was', 'l8r', 'malaria', 'and', 'that', 'you', 'know', 'that', 'we', 'miss', 'you', 'guys', 'i', 'miss', 'bani', 'big', 'so', 'pls', 'give', 'her', 'my', 'love', 'especially', 'have', 'a', 'great', 'day']
# ['called', 'hoping', 'l8r', 'malaria', 'know', 'miss', 'guys', 'miss', 'bani', 'big', 'pls', 'give', 'love', 'especially', 'great', 'day']
# ['good', 'afternoon', ',', 'my', 'love', '!', 'how', 'goes', 'that', 'day', '?', 'i', 'hope', 'maybe', 'you', 'got', 'some', 'leads', 'on', 'a', 'job', '.', 'i', 'think', 'of', 'you', ',', 'boytoy', 'and', 'send', 'you', 'a', 'passionate', 'kiss', 'from', 'across', 'the', 'sea']
# ['good', 'afternoon', 'my', 'love', 'how', 'goes', 'that', 'day', 'i', 'hope', 'maybe', 'you', 'got', 'some', 'leads', 'on', 'a', 'job', 'i', 'think', 'of', 'you', 'boytoy', 'and', 'send', 'you', 'a', 'passionate', 'kiss', 'from', 'across', 'the', 'sea']
# ['good', 'afternoon', 'love', 'goes', 'day', 'hope', 'maybe', 'got', 'leads', 'job', 'think', 'boytoy', 'send', 'passionate', 'kiss', 'across', 'sea']
# ['probably', 'gon', 'na', 'be', 'here', 'for', 'a', 'while', ',', 'see', 'you', 'later', 'tonight', '&', 'lt', ';', ')']
# ['probably', 'gon', 'na', 'be', 'here', 'for', 'a', 'while', 'see', 'you', 'later', 'tonight', 'lt']
# ['probably', 'gon', 'na', 'see', 'later', 'tonight', 'lt']
# ['or', 'maybe', 'my', 'fat', 'fingers', 'just', 'press', 'all', 'these', 'buttons', 'and', 'it', 'does', "n't", 'know', 'what', 'to', 'do', '.']
# ['or', 'maybe', 'my', 'fat', 'fingers', 'just', 'press', 'all', 'these', 'buttons', 'and', 'it', 'does', 'know', 'what', 'to', 'do']
# ['maybe', 'fat', 'fingers', 'press', 'buttons', 'know']
# ['ummmmmaah', 'many', 'many', 'happy', 'returns', 'of', 'd', 'day', 'my', 'dear', 'sweet', 'heart', '..', 'happy', 'birthday', 'dear']
# ['ummmmmaah', 'many', 'many', 'happy', 'returns', 'of', 'd', 'day', 'my', 'dear', 'sweet', 'heart', 'happy', 'birthday', 'dear']
# ['ummmmmaah', 'many', 'many', 'happy', 'returns', 'day', 'dear', 'sweet', 'heart', 'happy', 'birthday', 'dear']
# ['i', 'am', 'in', 'tirupur', 'da', ',', 'once', 'you', 'started', 'from', 'office', 'call', 'me', '.']
# ['i', 'am', 'in', 'tirupur', 'da', 'once', 'you', 'started', 'from', 'office', 'call', 'me']
# ['tirupur', 'da', 'started', 'office', 'call']
# ['from', 'www.applausestore.com', 'monthlysubscription', '@', '50p/msg', 'max6/month', 't', '&', 'csc', 'web', 'age16', '2stop', 'txt', 'stop']
# ['from', 'monthlysubscription', 't', 'csc', 'web', 'age16', '2stop', 'txt', 'stop']
# ['monthlysubscription', 'csc', 'web', 'age16', '2stop', 'txt', 'stop']
# ['a', 'famous', 'quote', ':', 'when', 'you', 'develop', 'the', 'ability', 'to', 'listen', 'to', "'anything", "'", 'unconditionally', 'without', 'losing', 'your', 'temper', 'or', 'self', 'confidence', ',', 'it', 'means', 'you', 'are', '.........', "'married", "'"]
# ['a', 'famous', 'quote', 'when', 'you', 'develop', 'the', 'ability', 'to', 'listen', 'to', 'unconditionally', 'without', 'losing', 'your', 'temper', 'or', 'self', 'confidence', 'it', 'means', 'you', 'are']
# ['famous', 'quote', 'develop', 'ability', 'listen', 'unconditionally', 'without', 'losing', 'temper', 'self', 'confidence', 'means']
# ['but', 'am', 'going', 'to', 'college', 'pa.', 'what', 'to', 'do', '.', 'are', 'else', 'ill', 'come', 'there', 'it', 'self', '.', 'pa', '.']
# ['but', 'am', 'going', 'to', 'college', 'what', 'to', 'do', 'are', 'else', 'ill', 'come', 'there', 'it', 'self', 'pa']
# ['going', 'college', 'else', 'ill', 'come', 'self', 'pa']
# ['4', 'oclock', 'at', 'mine', '.', 'just', 'to', 'bash', 'out', 'a', 'flat', 'plan', '.']
# ['4', 'oclock', 'at', 'mine', 'just', 'to', 'bash', 'out', 'a', 'flat', 'plan']
# ['4', 'oclock', 'mine', 'bash', 'flat', 'plan']
# ['this', 'girl', 'does', 'not', 'stay', 'in', 'bed', '.', 'this', 'girl', 'does', "n't", 'need', 'recovery', 'time', '.', 'id', 'rather', 'pass', 'out', 'while', 'having', 'fun', 'then', 'be', 'cooped', 'up', 'in', 'bed']
# ['this', 'girl', 'does', 'not', 'stay', 'in', 'bed', 'this', 'girl', 'does', 'need', 'recovery', 'time', 'id', 'rather', 'pass', 'out', 'while', 'having', 'fun', 'then', 'be', 'cooped', 'up', 'in', 'bed']
# ['girl', 'stay', 'bed', 'girl', 'need', 'recovery', 'time', 'id', 'rather', 'pass', 'fun', 'cooped', 'bed']
# ['then', 'any', 'special', 'there', '?']
# ['then', 'any', 'special', 'there']
# ['special']
# ['i', 'know', 'but', 'you', 'need', 'to', 'get', 'hotel', 'now', '.', 'i', 'just', 'got', 'my', 'invitation', 'but', 'i', 'had', 'to', 'apologise', '.', 'cali', 'is', 'to', 'sweet', 'for', 'me', 'to', 'come', 'to', 'some', 'english', 'bloke', "'s", 'weddin']
# ['i', 'know', 'but', 'you', 'need', 'to', 'get', 'hotel', 'now', 'i', 'just', 'got', 'my', 'invitation', 'but', 'i', 'had', 'to', 'apologise', 'cali', 'is', 'to', 'sweet', 'for', 'me', 'to', 'come', 'to', 'some', 'english', 'bloke', 'weddin']
# ['know', 'need', 'get', 'hotel', 'got', 'invitation', 'apologise', 'cali', 'sweet', 'come', 'english', 'bloke', 'weddin']
# ['sorry', 'that', 'took', 'so', 'long', ',', 'omw', 'now']
# ['sorry', 'that', 'took', 'so', 'long', 'omw', 'now']
# ['sorry', 'took', 'long', 'omw']
# ['wait', '&', 'lt', ';', '#', '&', 'gt', ';', 'min', '..']
# ['wait', 'lt', 'gt', 'min']
# ['wait', 'lt', 'gt', 'min']
# ['ok', 'give', 'me', '5', 'minutes', 'i', 'think', 'i', 'see', 'her', '.', 'btw', 'you', "'re", 'my', 'alibi', '.', 'you', 'were', 'cutting', 'my', 'hair', 'the', 'whole', 'time', '.']
# ['ok', 'give', 'me', '5', 'minutes', 'i', 'think', 'i', 'see', 'her', 'btw', 'you', 'my', 'alibi', 'you', 'were', 'cutting', 'my', 'hair', 'the', 'whole', 'time']
# ['ok', 'give', '5', 'minutes', 'think', 'see', 'btw', 'alibi', 'cutting', 'hair', 'whole', 'time']
# ['imagine', 'you', 'finally', 'get', 'to', 'sink', 'into', 'that', 'bath', 'after', 'i', 'have', 'put', 'you', 'through', 'your', 'paces', ',', 'maybe', 'even', 'having', 'you', 'eat', 'me', 'for', 'a', 'while', 'before', 'i', 'left', '...', 'but', 'also', 'imagine', 'the', 'feel', 'of', 'that', 'cage', 'on', 'your', 'cock', 'surrounded', 'by', 'the', 'bath', 'water', ',', 'reminding', 'you', 'always', 'who', 'owns', 'you', '...', 'enjoy', ',', 'my', 'cuck']
# ['imagine', 'you', 'finally', 'get', 'to', 'sink', 'into', 'that', 'bath', 'after', 'i', 'have', 'put', 'you', 'through', 'your', 'paces', 'maybe', 'even', 'having', 'you', 'eat', 'me', 'for', 'a', 'while', 'before', 'i', 'left', 'but', 'also', 'imagine', 'the', 'feel', 'of', 'that', 'cage', 'on', 'your', 'cock', 'surrounded', 'by', 'the', 'bath', 'water', 'reminding', 'you', 'always', 'who', 'owns', 'you', 'enjoy', 'my', 'cuck']
# ['imagine', 'finally', 'get', 'sink', 'bath', 'put', 'paces', 'maybe', 'even', 'eat', 'left', 'also', 'imagine', 'feel', 'cage', 'cock', 'surrounded', 'bath', 'water', 'reminding', 'always', 'owns', 'enjoy', 'cuck']
# ['hurry', 'up', ',', 'i', "'ve", 'been', 'weed-deficient', 'for', 'like', 'three', 'days']
# ['hurry', 'up', 'i', 'been', 'for', 'like', 'three', 'days']
# ['hurry', 'like', 'three', 'days']
# ['sure', ',', 'if', 'i', 'get', 'an', 'acknowledgement', 'from', 'you', 'that', 'it', "'s", 'astoundingly', 'tactless', 'and', 'generally', 'faggy', 'to', 'demand', 'a', 'blood', 'oath', 'fo']
# ['sure', 'if', 'i', 'get', 'an', 'acknowledgement', 'from', 'you', 'that', 'it', 'astoundingly', 'tactless', 'and', 'generally', 'faggy', 'to', 'demand', 'a', 'blood', 'oath', 'fo']
# ['sure', 'get', 'acknowledgement', 'astoundingly', 'tactless', 'generally', 'faggy', 'demand', 'blood', 'oath', 'fo']
# ['ok.', 'every', 'night', 'take', 'a', 'warm', 'bath', 'drink', 'a', 'cup', 'of', 'milk', 'and', 'you', "'ll", 'see', 'a', 'work', 'of', 'magic', '.', 'you', 'still', 'need', 'to', 'loose', 'weight', '.', 'just', 'so', 'that', 'you', 'know']
# ['every', 'night', 'take', 'a', 'warm', 'bath', 'drink', 'a', 'cup', 'of', 'milk', 'and', 'you', 'see', 'a', 'work', 'of', 'magic', 'you', 'still', 'need', 'to', 'loose', 'weight', 'just', 'so', 'that', 'you', 'know']
# ['every', 'night', 'take', 'warm', 'bath', 'drink', 'cup', 'milk', 'see', 'work', 'magic', 'still', 'need', 'loose', 'weight', 'know']
# ['i‰û÷ll', 'have', 'a', 'look', 'at', 'the', 'frying', 'pan', 'in', 'case', 'it‰û÷s', 'cheap', 'or', 'a', 'book', 'perhaps', '.', 'no', 'that‰û÷s', 'silly', 'a', 'frying', 'pan', 'isn‰û÷t', 'likely', 'to', 'be', 'a', 'book']
# ['have', 'a', 'look', 'at', 'the', 'frying', 'pan', 'in', 'case', 'cheap', 'or', 'a', 'book', 'perhaps', 'no', 'silly', 'a', 'frying', 'pan', 'likely', 'to', 'be', 'a', 'book']
# ['look', 'frying', 'pan', 'case', 'cheap', 'book', 'perhaps', 'silly', 'frying', 'pan', 'likely', 'book']
# ['o.', 'well', 'uv', 'causes', 'mutations', '.', 'sunscreen', 'is', 'like', 'essential', 'thesedays']
# ['well', 'uv', 'causes', 'mutations', 'sunscreen', 'is', 'like', 'essential', 'thesedays']
# ['well', 'uv', 'causes', 'mutations', 'sunscreen', 'like', 'essential', 'thesedays']
# ['having', 'lunch', ':', ')', 'you', 'are', 'not', 'in', 'online', '?', 'why', '?']
# ['having', 'lunch', 'you', 'are', 'not', 'in', 'online', 'why']
# ['lunch', 'online']
# ['i', 'know', 'that', 'my', 'friend', 'already', 'told', 'that', '.']
# ['i', 'know', 'that', 'my', 'friend', 'already', 'told', 'that']
# ['know', 'friend', 'already', 'told']
# ['hi', 'princess', '!', 'thank', 'you', 'for', 'the', 'pics', '.', 'you', 'are', 'very', 'pretty', '.', 'how', 'are', 'you', '?']
# ['hi', 'princess', 'thank', 'you', 'for', 'the', 'pics', 'you', 'are', 'very', 'pretty', 'how', 'are', 'you']
# ['hi', 'princess', 'thank', 'pics', 'pretty']
# ['aiyo', '...', 'u', 'always', 'c', 'our', 'ex', 'one', '...', 'i', 'dunno', 'abt', 'mei', ',', 'she', 'haven', 'reply', '...', 'first', 'time', 'u', 'reply', 'so', 'fast', '...', 'y', 'so', 'lucky', 'not', 'workin', 'huh', ',', 'got', 'bao', 'by', 'ur', 'sugardad', 'ah', '...', 'gee', '..']
# ['aiyo', 'u', 'always', 'c', 'our', 'ex', 'one', 'i', 'dunno', 'abt', 'mei', 'she', 'haven', 'reply', 'first', 'time', 'u', 'reply', 'so', 'fast', 'y', 'so', 'lucky', 'not', 'workin', 'huh', 'got', 'bao', 'by', 'ur', 'sugardad', 'ah', 'gee']
# ['aiyo', 'u', 'always', 'c', 'ex', 'one', 'dunno', 'abt', 'mei', 'reply', 'first', 'time', 'u', 'reply', 'fast', 'lucky', 'workin', 'huh', 'got', 'bao', 'ur', 'sugardad', 'ah', 'gee']
# ['hi', 'msg', 'me', ':', ')', 'i', "'m", 'in', 'office', '..']
# ['hi', 'msg', 'me', 'i', 'in', 'office']
# ['hi', 'msg', 'office']
# ['thanx', '4', 'e', 'brownie', 'it', "'s", 'v', 'nice', '...']
# ['thanx', '4', 'e', 'brownie', 'it', 'v', 'nice']
# ['thanx', '4', 'e', 'brownie', 'v', 'nice']
# ['geeeee', '...', 'i', 'love', 'you', 'so', 'much', 'i', 'can', 'barely', 'stand', 'it']
# ['geeeee', 'i', 'love', 'you', 'so', 'much', 'i', 'can', 'barely', 'stand', 'it']
# ['geeeee', 'love', 'much', 'barely', 'stand']
# ['gent', '!', 'we', 'are', 'trying', 'to', 'contact', 'you', '.', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'won', 'a', 'å£1000', 'prize', 'guaranteed', '.', 'call', '09064012160.', 'claim', 'code', 'k52', '.', 'valid', '12hrs', 'only', '.', '150ppm']
# ['gent', 'we', 'are', 'trying', 'to', 'contact', 'you', 'last', 'weekends', 'draw', 'shows', 'that', 'you', 'won', 'a', 'prize', 'guaranteed', 'call', 'claim', 'code', 'k52', 'valid', '12hrs', 'only', '150ppm']
# ['gent', 'trying', 'contact', 'last', 'weekends', 'draw', 'shows', 'prize', 'guaranteed', 'call', 'claim', 'code', 'k52', 'valid', '12hrs', '150ppm']
# ['fuck', 'babe', '...', 'i', 'miss', 'you', 'already', ',', 'you', 'know', '?', 'ca', "n't", 'you', 'let', 'me', 'send', 'you', 'some', 'money', 'towards', 'your', 'net', '?', 'i', 'need', 'you', '...', 'i', 'want', 'you', '...', 'i', 'crave', 'you', '...']
# ['fuck', 'babe', 'i', 'miss', 'you', 'already', 'you', 'know', 'ca', 'you', 'let', 'me', 'send', 'you', 'some', 'money', 'towards', 'your', 'net', 'i', 'need', 'you', 'i', 'want', 'you', 'i', 'crave', 'you']
# ['fuck', 'babe', 'miss', 'already', 'know', 'ca', 'let', 'send', 'money', 'towards', 'net', 'need', 'want', 'crave']
# ['ill', 'call', 'u', '2mrw', 'at', 'ninish', ',', 'with', 'my', 'address', 'that', 'icky', 'american', 'freek', 'wont', 'stop', 'callin', 'me', '2', 'bad', 'jen', 'k', 'eh', '?']
# ['ill', 'call', 'u', '2mrw', 'at', 'ninish', 'with', 'my', 'address', 'that', 'icky', 'american', 'freek', 'wont', 'stop', 'callin', 'me', '2', 'bad', 'jen', 'k', 'eh']
# ['ill', 'call', 'u', '2mrw', 'ninish', 'address', 'icky', 'american', 'freek', 'wont', 'stop', 'callin', '2', 'bad', 'jen', 'k', 'eh']
# ['oooh', 'bed', 'ridden', 'ey', '?', 'what', 'are', 'you', 'thinking', 'of', '?']
# ['oooh', 'bed', 'ridden', 'ey', 'what', 'are', 'you', 'thinking', 'of']
# ['oooh', 'bed', 'ridden', 'ey', 'thinking']
# ['so', 'anyways', ',', 'you', 'can', 'just', 'go', 'to', 'your', 'gym', 'or', 'whatever', ',', 'my', 'love', '*', 'smiles', '*', 'i', 'hope', 'your', 'ok', 'and', 'having', 'a', 'good', 'day', 'babe', '...', 'i', 'miss', 'you', 'so', 'much', 'already']
# ['so', 'anyways', 'you', 'can', 'just', 'go', 'to', 'your', 'gym', 'or', 'whatever', 'my', 'love', 'smiles', 'i', 'hope', 'your', 'ok', 'and', 'having', 'a', 'good', 'day', 'babe', 'i', 'miss', 'you', 'so', 'much', 'already']
# ['anyways', 'go', 'gym', 'whatever', 'love', 'smiles', 'hope', 'ok', 'good', 'day', 'babe', 'miss', 'much', 'already']
# ['love', 'it', '!', 'daddy', 'will', 'make', 'you', 'scream', 'with', 'pleasure', '!', 'i', 'am', 'going', 'to', 'slap', 'your', 'ass', 'with', 'my', 'dick', '!']
# ['love', 'it', 'daddy', 'will', 'make', 'you', 'scream', 'with', 'pleasure', 'i', 'am', 'going', 'to', 'slap', 'your', 'ass', 'with', 'my', 'dick']
# ['love', 'daddy', 'make', 'scream', 'pleasure', 'going', 'slap', 'ass', 'dick']
# ['wot', 'u', 'wan', 'na', 'do', 'then', 'missy', '?']
# ['wot', 'u', 'wan', 'na', 'do', 'then', 'missy']
# ['wot', 'u', 'wan', 'na', 'missy']
# ['yar', 'lor', 'wait', '4', 'my', 'mum', '2', 'finish', 'sch', 'then', 'have', 'lunch', 'lor', '...', 'i', 'whole', 'morning', 'stay', 'at', 'home', 'clean', 'my', 'room', 'now', 'my', 'room', 'quite', 'clean', '...', 'hee', '...']
# ['yar', 'lor', 'wait', '4', 'my', 'mum', '2', 'finish', 'sch', 'then', 'have', 'lunch', 'lor', 'i', 'whole', 'morning', 'stay', 'at', 'home', 'clean', 'my', 'room', 'now', 'my', 'room', 'quite', 'clean', 'hee']
# ['yar', 'lor', 'wait', '4', 'mum', '2', 'finish', 'sch', 'lunch', 'lor', 'whole', 'morning', 'stay', 'home', 'clean', 'room', 'room', 'quite', 'clean', 'hee']
# ['do', 'you', 'know', 'where', 'my', 'lab', 'goggles', 'went']
# ['do', 'you', 'know', 'where', 'my', 'lab', 'goggles', 'went']
# ['know', 'lab', 'goggles', 'went']
# ['can', 'you', 'open', 'the', 'door', '?']
# ['can', 'you', 'open', 'the', 'door']
# ['open', 'door']
# ['waiting', 'for', 'your', 'call', '.']
# ['waiting', 'for', 'your', 'call']
# ['waiting', 'call']
# ['nope', 'i', 'waiting', 'in', 'sch', '4', 'daddy', '...']
# ['nope', 'i', 'waiting', 'in', 'sch', '4', 'daddy']
# ['nope', 'waiting', 'sch', '4', 'daddy']
# ['you', 'have', 'won', '?', '1,000', 'cash', 'or', 'a', '?', '2,000', 'prize', '!', 'to', 'claim', ',', 'call09050000327']
# ['you', 'have', 'won', 'cash', 'or', 'a', 'prize', 'to', 'claim', 'call09050000327']
# ['cash', 'prize', 'claim', 'call09050000327']
# ['i', "'m", 'tired', 'of', 'arguing', 'with', 'you', 'about', 'this', 'week', 'after', 'week', '.', 'do', 'what', 'you', 'want', 'and', 'from', 'now', 'on', ',', 'i', "'ll", 'do', 'the', 'same', '.']
# ['i', 'tired', 'of', 'arguing', 'with', 'you', 'about', 'this', 'week', 'after', 'week', 'do', 'what', 'you', 'want', 'and', 'from', 'now', 'on', 'i', 'do', 'the', 'same']
# ['tired', 'arguing', 'week', 'week', 'want']
# ['ìï', 'wait', '4', 'me', 'in', 'sch', 'i', 'finish', 'ard', '5', '..']
# ['ìï', 'wait', '4', 'me', 'in', 'sch', 'i', 'finish', 'ard', '5']
# ['ìï', 'wait', '4', 'sch', 'finish', 'ard', '5']
# ['our', 'mobile', 'number', 'has', 'won', 'å£5000', ',', 'to', 'claim', 'calls', 'us', 'back', 'or', 'ring', 'the', 'claims', 'hot', 'line', 'on', '09050005321', '.']
# ['our', 'mobile', 'number', 'has', 'won', 'to', 'claim', 'calls', 'us', 'back', 'or', 'ring', 'the', 'claims', 'hot', 'line', 'on', '09050005321']
# ['mobile', 'number', 'claim', 'calls', 'us', 'back', 'ring', 'claims', 'hot', 'line', '09050005321']
# ['arngd', 'marriage', 'is', 'while', 'u', 'r', 'walkin', 'unfortuntly', 'a', 'snake', 'bites', 'u.', 'bt', 'love', 'marriage', 'is', 'dancing', 'in', 'frnt', 'of', 'd', 'snake', '&', 'amp', ';', 'sayin', 'bite', 'me', ',', 'bite', 'me', '.']
# ['arngd', 'marriage', 'is', 'while', 'u', 'r', 'walkin', 'unfortuntly', 'a', 'snake', 'bites', 'bt', 'love', 'marriage', 'is', 'dancing', 'in', 'frnt', 'of', 'd', 'snake', 'amp', 'sayin', 'bite', 'me', 'bite', 'me']
# ['arngd', 'marriage', 'u', 'r', 'walkin', 'unfortuntly', 'snake', 'bites', 'bt', 'love', 'marriage', 'dancing', 'frnt', 'snake', 'amp', 'sayin', 'bite', 'bite']
# ['huh', 'so', 'early', '..', 'then', 'ì_', 'having', 'dinner', 'outside', 'izzit', '?']
# ['huh', 'so', 'early', 'then', 'having', 'dinner', 'outside', 'izzit']
# ['huh', 'early', 'dinner', 'outside', 'izzit']
# ['ok', 'anyway', 'no', 'need', 'to', 'change', 'with', 'what', 'you', 'said']
# ['ok', 'anyway', 'no', 'need', 'to', 'change', 'with', 'what', 'you', 'said']
# ['ok', 'anyway', 'need', 'change', 'said']
# ['we', 'tried', 'to', 'contact', 'you', 're', 'your', 'reply', 'to', 'our', 'offer', 'of', '750', 'mins', '150', 'textand', 'a', 'new', 'video', 'phone', 'call', '08002988890', 'now', 'or', 'reply', 'for', 'free', 'delivery', 'tomorrow']
# ['we', 'tried', 'to', 'contact', 'you', 're', 'your', 'reply', 'to', 'our', 'offer', 'of', '750', 'mins', '150', 'textand', 'a', 'new', 'video', 'phone', 'call', '08002988890', 'now', 'or', 'reply', 'for', 'free', 'delivery', 'tomorrow']
# ['tried', 'contact', 'reply', 'offer', '750', 'mins', '150', 'textand', 'new', 'video', 'phone', 'call', '08002988890', 'reply', 'free', 'delivery', 'tomorrow']
# ['my', 'ex-wife', 'was', 'not', 'able', 'to', 'have', 'kids', '.', 'do', 'you', 'want', 'kids', 'one', 'day', '?']
# ['my', 'was', 'not', 'able', 'to', 'have', 'kids', 'do', 'you', 'want', 'kids', 'one', 'day']
# ['able', 'kids', 'want', 'kids', 'one', 'day']
# ['so', 'how', "'s", 'scotland', '.', 'hope', 'you', 'are', 'not', 'over', 'showing', 'your', 'jjc', 'tendencies', '.', 'take', 'care', '.', 'live', 'the', 'dream']
# ['so', 'how', 'scotland', 'hope', 'you', 'are', 'not', 'over', 'showing', 'your', 'jjc', 'tendencies', 'take', 'care', 'live', 'the', 'dream']
# ['scotland', 'hope', 'showing', 'jjc', 'tendencies', 'take', 'care', 'live', 'dream']
# ['tell', 'them', 'u', 'have', 'a', 'headache', 'and', 'just', 'want', 'to', 'use', '1', 'hour', 'of', 'sick', 'time', '.']
# ['tell', 'them', 'u', 'have', 'a', 'headache', 'and', 'just', 'want', 'to', 'use', '1', 'hour', 'of', 'sick', 'time']
# ['tell', 'u', 'headache', 'want', 'use', '1', 'hour', 'sick', 'time']
# ['i', 'dun', 'thk', 'i', "'ll", 'quit', 'yet', '...', 'hmmm', ',', 'can', 'go', 'jazz', '?', 'yogasana', 'oso', 'can', '...', 'we', 'can', 'go', 'meet', 'em', 'after', 'our', 'lessons', 'den', '...']
# ['i', 'dun', 'thk', 'i', 'quit', 'yet', 'hmmm', 'can', 'go', 'jazz', 'yogasana', 'oso', 'can', 'we', 'can', 'go', 'meet', 'em', 'after', 'our', 'lessons', 'den']
# ['dun', 'thk', 'quit', 'yet', 'hmmm', 'go', 'jazz', 'yogasana', 'oso', 'go', 'meet', 'em', 'lessons', 'den']
# ['\\pete', 'can', 'you', 'please', 'ring', 'meive', 'hardly', 'gotany', 'credit\\', "''", "''"]
# ['can', 'you', 'please', 'ring', 'meive', 'hardly', 'gotany']
# ['please', 'ring', 'meive', 'hardly', 'gotany']
# ['ya', 'srsly', 'better', 'than', 'yi', 'tho']
# ['ya', 'srsly', 'better', 'than', 'yi', 'tho']
# ['ya', 'srsly', 'better', 'yi', 'tho']
# ['i', "'m", 'in', 'a', 'meeting', ',', 'call', 'me', 'later', 'at']
# ['i', 'in', 'a', 'meeting', 'call', 'me', 'later', 'at']
# ['meeting', 'call', 'later']
# ['for', 'ur', 'chance', 'to', 'win', 'a', 'å£250', 'wkly', 'shopping', 'spree', 'txt', ':', 'shop', 'to', '80878.', 't', "'s", '&', 'c', "'s", 'www.txt-2-shop.com', 'custcare', '08715705022', ',', '1x150p/wk']
# ['for', 'ur', 'chance', 'to', 'win', 'a', 'wkly', 'shopping', 'spree', 'txt', 'shop', 'to', 't', 'c', 'custcare', '08715705022']
# ['ur', 'chance', 'win', 'wkly', 'shopping', 'spree', 'txt', 'shop', 'c', 'custcare', '08715705022']
# ['you', 'have', 'been', 'specially', 'selected', 'to', 'receive', 'a', '2000', 'pound', 'award', '!', 'call', '08712402050', 'before', 'the', 'lines', 'close', '.', 'cost', '10ppm', '.', '16+', '.', 't', '&', 'cs', 'apply', '.', 'ag', 'promo']
# ['you', 'have', 'been', 'specially', 'selected', 'to', 'receive', 'a', '2000', 'pound', 'award', 'call', '08712402050', 'before', 'the', 'lines', 'close', 'cost', '10ppm', 't', 'cs', 'apply', 'ag', 'promo']
# ['specially', 'selected', 'receive', '2000', 'pound', 'award', 'call', '08712402050', 'lines', 'close', 'cost', '10ppm', 'cs', 'apply', 'ag', 'promo']
# ['private', '!', 'your', '2003', 'account', 'statement', 'for', '07753741225', 'shows', '800', 'un-redeemed', 's.', 'i.', 'm.', 'points', '.', 'call', '08715203677', 'identifier', 'code', ':', '42478', 'expires', '24/10/04']
# ['private', 'your', '2003', 'account', 'statement', 'for', '07753741225', 'shows', '800', 'points', 'call', '08715203677', 'identifier', 'code', '42478', 'expires']
# ['private', '2003', 'account', 'statement', '07753741225', 'shows', '800', 'points', 'call', '08715203677', 'identifier', 'code', '42478', 'expires']
# ['you', 'still', 'at', 'grand', 'prix', '?']
# ['you', 'still', 'at', 'grand', 'prix']
# ['still', 'grand', 'prix']
# ['i', 'met', 'you', 'as', 'a', 'stranger', 'and', 'choose', 'you', 'as', 'my', 'friend', '.', 'as', 'long', 'as', 'the', 'world', 'stands', ',', 'our', 'friendship', 'never', 'ends', '.', 'lets', 'be', 'friends', 'forever', '!', '!', '!', 'gud', 'nitz', '...']
# ['i', 'met', 'you', 'as', 'a', 'stranger', 'and', 'choose', 'you', 'as', 'my', 'friend', 'as', 'long', 'as', 'the', 'world', 'stands', 'our', 'friendship', 'never', 'ends', 'lets', 'be', 'friends', 'forever', 'gud', 'nitz']
# ['met', 'stranger', 'choose', 'friend', 'long', 'world', 'stands', 'friendship', 'never', 'ends', 'lets', 'friends', 'forever', 'gud', 'nitz']
# ['i', 'am', 'great', '!', 'how', 'are', 'you', '?']
# ['i', 'am', 'great', 'how', 'are', 'you']
# ['great']
# ['gud', 'mrng', 'dear', 'have', 'a', 'nice', 'day']
# ['gud', 'mrng', 'dear', 'have', 'a', 'nice', 'day']
# ['gud', 'mrng', 'dear', 'nice', 'day']
# ['you', 'have', 'an', 'important', 'customer', 'service', 'announcement', '.', 'call', 'freephone', '0800', '542', '0825', 'now', '!']
# ['you', 'have', 'an', 'important', 'customer', 'service', 'announcement', 'call', 'freephone', '0800', '542', '0825', 'now']
# ['important', 'customer', 'service', 'announcement', 'call', 'freephone', '0800', '542', '0825']
# ['will', 'do', '.', 'was', 'exhausted', 'on', 'train', 'this', 'morning', '.', 'too', 'much', 'wine', 'and', 'pie', '.', 'you', 'sleep', 'well', 'too']
# ['will', 'do', 'was', 'exhausted', 'on', 'train', 'this', 'morning', 'too', 'much', 'wine', 'and', 'pie', 'you', 'sleep', 'well', 'too']
# ['exhausted', 'train', 'morning', 'much', 'wine', 'pie', 'sleep', 'well']
# ['i', "'m", 'going', 'out', 'to', 'buy', 'mum', "'s", 'present', 'ar', '.']
# ['i', 'going', 'out', 'to', 'buy', 'mum', 'present', 'ar']
# ['going', 'buy', 'mum', 'present', 'ar']
# ['mind', 'blastin', '..', 'no', 'more', 'tsunamis', 'will', 'occur', 'from', 'now', 'on', '..', 'rajnikant', 'stopped', 'swimming', 'in', 'indian', 'ocean', '..', ':', '-d']
# ['mind', 'blastin', 'no', 'more', 'tsunamis', 'will', 'occur', 'from', 'now', 'on', 'rajnikant', 'stopped', 'swimming', 'in', 'indian', 'ocean']
# ['mind', 'blastin', 'tsunamis', 'occur', 'rajnikant', 'stopped', 'swimming', 'indian', 'ocean']
# ['if', 'u', 'sending', 'her', 'home', 'first', 'it', "'s", 'ok', 'lor', '.', 'i', "'m", 'not', 'ready', 'yet', '.']
# ['if', 'u', 'sending', 'her', 'home', 'first', 'it', 'ok', 'lor', 'i', 'not', 'ready', 'yet']
# ['u', 'sending', 'home', 'first', 'ok', 'lor', 'ready', 'yet']
# ['speaking', 'of', 'does', 'he', 'have', 'any', 'cash', 'yet', '?']
# ['speaking', 'of', 'does', 'he', 'have', 'any', 'cash', 'yet']
# ['speaking', 'cash', 'yet']
# ['be', 'happy', 'there', '.', 'i', 'will', 'come', 'after', 'noon']
# ['be', 'happy', 'there', 'i', 'will', 'come', 'after', 'noon']
# ['happy', 'come', 'noon']
# ['meet', 'after', 'lunch', 'la', '...']
# ['meet', 'after', 'lunch', 'la']
# ['meet', 'lunch', 'la']
# ['take', 'care', 'n', 'get', 'well', 'soon']
# ['take', 'care', 'n', 'get', 'well', 'soon']
# ['take', 'care', 'n', 'get', 'well', 'soon']
# ['xclusive', '@', 'clubsaisai', '2morow', '28/5', 'soiree', 'speciale', 'zouk', 'with', 'nichols', 'from', 'paris.free', 'roses', '2', 'all', 'ladies', '!', '!', '!', 'info', ':', '07946746291/07880867867']
# ['xclusive', 'clubsaisai', '2morow', 'soiree', 'speciale', 'zouk', 'with', 'nichols', 'from', 'roses', '2', 'all', 'ladies', 'info']
# ['xclusive', 'clubsaisai', '2morow', 'soiree', 'speciale', 'zouk', 'nichols', 'roses', '2', 'ladies', 'info']
# ['what', 'i', 'meant', 'to', 'say', 'is', 'cant', 'wait', 'to', 'see', 'u', 'again', 'getting', 'bored', 'of', 'this', 'bridgwater', 'banter']
# ['what', 'i', 'meant', 'to', 'say', 'is', 'cant', 'wait', 'to', 'see', 'u', 'again', 'getting', 'bored', 'of', 'this', 'bridgwater', 'banter']
# ['meant', 'say', 'cant', 'wait', 'see', 'u', 'getting', 'bored', 'bridgwater', 'banter']
# ['neva', 'mind', 'it', "'s", 'ok', '..']
# ['neva', 'mind', 'it', 'ok']
# ['neva', 'mind', 'ok']
# ['it', "'s", 'fine', ',', 'imma', 'get', 'a', 'drink', 'or', 'somethin', '.', 'want', 'me', 'to', 'come', 'find', 'you', '?']
# ['it', 'fine', 'imma', 'get', 'a', 'drink', 'or', 'somethin', 'want', 'me', 'to', 'come', 'find', 'you']
# ['fine', 'imma', 'get', 'drink', 'somethin', 'want', 'come', 'find']
# ['22', 'days', 'to', 'kick', 'off', '!', 'for', 'euro2004', 'u', 'will', 'be', 'kept', 'up', 'to', 'date', 'with', 'the', 'latest', 'news', 'and', 'results', 'daily', '.', 'to', 'be', 'removed', 'send', 'get', 'txt', 'stop', 'to', '83222']
# ['22', 'days', 'to', 'kick', 'off', 'for', 'euro2004', 'u', 'will', 'be', 'kept', 'up', 'to', 'date', 'with', 'the', 'latest', 'news', 'and', 'results', 'daily', 'to', 'be', 'removed', 'send', 'get', 'txt', 'stop', 'to', '83222']
# ['22', 'days', 'kick', 'euro2004', 'u', 'kept', 'date', 'latest', 'news', 'results', 'daily', 'removed', 'send', 'get', 'txt', 'stop', '83222']
# ['its', 'a', 'valentine', 'game', '.', '.', '.', 'send', 'dis', 'msg', 'to', 'all', 'ur', 'friends', '.', '..', 'if', '5', 'answers', 'r', 'd', 'same', 'then', 'someone', 'really', 'loves', 'u.', 'ques-', 'which', 'colour', 'suits', 'me', 'the', 'best', '?', 'rply', 'me']
# ['its', 'a', 'valentine', 'game', 'send', 'dis', 'msg', 'to', 'all', 'ur', 'friends', 'if', '5', 'answers', 'r', 'd', 'same', 'then', 'someone', 'really', 'loves', 'which', 'colour', 'suits', 'me', 'the', 'best', 'rply', 'me']
# ...
# ['by', 'the', 'way', 'i', 'put', 'a', 'skip', 'right', 'outside', 'the', 'front', 'of', 'the', 'house', 'so', 'you', 'can', 'see', 'which', 'house', 'it', 'is', 'just', 'pull', 'up', 'before', 'it']
# ['way', 'put', 'skip', 'right', 'outside', 'front', 'house', 'see', 'house', 'pull']
# ['can', 'you', 'pls', 'send', 'me', 'that', 'company', 'name', '.', 'in', 'saibaba', 'colany']
# ['can', 'you', 'pls', 'send', 'me', 'that', 'company', 'name', 'in', 'saibaba', 'colany']
# ['pls', 'send', 'company', 'name', 'saibaba', 'colany']
# ['no', '.', 'i', 'dont', 'want', 'to', 'hear', 'anything']
# ['no', 'i', 'dont', 'want', 'to', 'hear', 'anything']
# ['dont', 'want', 'hear', 'anything']
# ['you', 'are', 'a', 'big', 'chic', '.', 'common', '.', 'declare']
# ['you', 'are', 'a', 'big', 'chic', 'common', 'declare']
# ['big', 'chic', 'common', 'declare']
# ['thats', 'cool', '.', 'i', 'want', 'to', 'please', 'you', '...']
# ['thats', 'cool', 'i', 'want', 'to', 'please', 'you']
# ['thats', 'cool', 'want', 'please']
# ['going', 'to', 'join', 'tomorrow', '.']
# ['going', 'to', 'join', 'tomorrow']
# ['going', 'join', 'tomorrow']
# ['i', 'want', 'to', 'tell', 'you', 'how', 'bad', 'i', 'feel', 'that', 'basically', 'the', 'only', 'times', 'i', 'text', 'you', 'lately', 'are', 'when', 'i', 'need', 'drugs']
# ['i', 'want', 'to', 'tell', 'you', 'how', 'bad', 'i', 'feel', 'that', 'basically', 'the', 'only', 'times', 'i', 'text', 'you', 'lately', 'are', 'when', 'i', 'need', 'drugs']
# ['want', 'tell', 'bad', 'feel', 'basically', 'times', 'text', 'lately', 'need', 'drugs']
# ['private', '!', 'your', '2003', 'account', 'statement', 'for', 'shows', '800', 'un-redeemed', 's.i.m', '.', 'points', '.', 'call', '08718738001', 'identifier', 'code', ':', '49557', 'expires', '26/11/04']
# ['private', 'your', '2003', 'account', 'statement', 'for', 'shows', '800', 'points', 'call', '08718738001', 'identifier', 'code', '49557', 'expires']
# ['private', '2003', 'account', 'statement', 'shows', '800', 'points', 'call', '08718738001', 'identifier', 'code', '49557', 'expires']
# ['total', 'disappointment', ',', 'when', 'i', 'texted', 'you', 'was', 'the', 'craziest', 'shit', 'got', ':', '(']
# ['total', 'disappointment', 'when', 'i', 'texted', 'you', 'was', 'the', 'craziest', 'shit', 'got']
# ['total', 'disappointment', 'texted', 'craziest', 'shit', 'got']
# ['its', 'just', 'the', 'effect', 'of', 'irritation', '.', 'just', 'ignore', 'it']
# ['its', 'just', 'the', 'effect', 'of', 'irritation', 'just', 'ignore', 'it']
# ['effect', 'irritation', 'ignore']
# ['what', 'about', 'this', 'one', 'then', '.']
# ['what', 'about', 'this', 'one', 'then']
# ['one']
# ['i', 'think', 'that', 'tantrum', "'s", 'finished', 'so', 'yeah', 'i', "'ll", 'be', 'by', 'at', 'some', 'point']
# ['i', 'think', 'that', 'tantrum', 'finished', 'so', 'yeah', 'i', 'be', 'by', 'at', 'some', 'point']
# ['think', 'tantrum', 'finished', 'yeah', 'point']
# ['compliments', 'to', 'you', '.', 'was', 'away', 'from', 'the', 'system', '.', 'how', 'your', 'side', '.']
# ['compliments', 'to', 'you', 'was', 'away', 'from', 'the', 'system', 'how', 'your', 'side']
# ['compliments', 'away', 'system', 'side']
# ['happened', 'here', 'while', 'you', 'were', 'adventuring']
# ['happened', 'here', 'while', 'you', 'were', 'adventuring']
# ['happened', 'adventuring']
# ['hey', 'chief', ',', 'can', 'you', 'give', 'me', 'a', 'bell', 'when', 'you', 'get', 'this', '.', 'need', 'to', 'talk', 'to', 'you', 'about', 'this', 'royal', 'visit', 'on', 'the', '1st', 'june', '.']
# ['hey', 'chief', 'can', 'you', 'give', 'me', 'a', 'bell', 'when', 'you', 'get', 'this', 'need', 'to', 'talk', 'to', 'you', 'about', 'this', 'royal', 'visit', 'on', 'the', '1st', 'june']
# ['hey', 'chief', 'give', 'bell', 'get', 'need', 'talk', 'royal', 'visit', '1st', 'june']
# ['ok', 'which', 'your', 'another', 'number']
# ['ok', 'which', 'your', 'another', 'number']
# ['ok', 'another', 'number']
# ['aiyah', 'ok', 'wat', 'as', 'long', 'as', 'got', 'improve', 'can', 'already', 'wat', '...']
# ['aiyah', 'ok', 'wat', 'as', 'long', 'as', 'got', 'improve', 'can', 'already', 'wat']
# ['aiyah', 'ok', 'wat', 'long', 'got', 'improve', 'already', 'wat']
# ['want', 'explicit', 'sex', 'in', '30', 'secs', '?', 'ring', '02073162414', 'now', '!', 'costs', '20p/min', 'gsex', 'pobox', '2667', 'wc1n', '3xx']
# ['want', 'explicit', 'sex', 'in', '30', 'secs', 'ring', '02073162414', 'now', 'costs', 'gsex', 'pobox', '2667', 'wc1n', '3xx']
# ['want', 'explicit', 'sex', '30', 'secs', 'ring', '02073162414', 'costs', 'gsex', 'pobox', '2667', 'wc1n', '3xx']
# ['i', 'ca', "n't", 'believe', 'how', 'attached', 'i', 'am', 'to', 'seeing', 'you', 'every', 'day', '.', 'i', 'know', 'you', 'will', 'do', 'the', 'best', 'you', 'can', 'to', 'get', 'to', 'me', 'babe', '.', 'i', 'will', 'go', 'to', 'teach', 'my', 'class', 'at', 'your', 'midnight']
# ['i', 'ca', 'believe', 'how', 'attached', 'i', 'am', 'to', 'seeing', 'you', 'every', 'day', 'i', 'know', 'you', 'will', 'do', 'the', 'best', 'you', 'can', 'to', 'get', 'to', 'me', 'babe', 'i', 'will', 'go', 'to', 'teach', 'my', 'class', 'at', 'your', 'midnight']
# ['ca', 'believe', 'attached', 'seeing', 'every', 'day', 'know', 'best', 'get', 'babe', 'go', 'teach', 'class', 'midnight']
# ['asked', '3mobile', 'if', '0870', 'chatlines', 'inclu', 'in', 'free', 'mins', '.', 'india', 'cust', 'servs', 'sed', 'yes', '.', 'l8er', 'got', 'mega', 'bill', '.', '3', 'dont', 'giv', 'a', 'shit', '.', 'bailiff', 'due', 'in', 'days', '.', 'i', 'o', 'å£250', '3', 'want', 'å£800']
# ['asked', '3mobile', 'if', '0870', 'chatlines', 'inclu', 'in', 'free', 'mins', 'india', 'cust', 'servs', 'sed', 'yes', 'l8er', 'got', 'mega', 'bill', '3', 'dont', 'giv', 'a', 'shit', 'bailiff', 'due', 'in', 'days', 'i', 'o', '3', 'want']
# ['asked', '3mobile', '0870', 'chatlines', 'inclu', 'free', 'mins', 'india', 'cust', 'servs', 'sed', 'yes', 'l8er', 'got', 'mega', 'bill', '3', 'dont', 'giv', 'shit', 'bailiff', 'due', 'days', '3', 'want']
# ['yeah', 'it', "'s", 'jus', 'rite', '...']
# ['yeah', 'it', 'jus', 'rite']
# ['yeah', 'jus', 'rite']
# ['armand', 'says', 'get', 'your', 'ass', 'over', 'to', 'epsilon']
# ['armand', 'says', 'get', 'your', 'ass', 'over', 'to', 'epsilon']
# ['armand', 'says', 'get', 'ass', 'epsilon']
# ['u', 'still', 'havent', 'got', 'urself', 'a', 'jacket', 'ah', '?']
# ['u', 'still', 'havent', 'got', 'urself', 'a', 'jacket', 'ah']
# ['u', 'still', 'havent', 'got', 'urself', 'jacket', 'ah']
# ['i', "'m", 'taking', 'derek', '&', 'amp', ';', 'taylor', 'to', 'walmart', ',', 'if', 'i', "'m", 'not', 'back', 'by', 'the', 'time', 'you', "'re", 'done', 'just', 'leave', 'the', 'mouse', 'on', 'my', 'desk', 'and', 'i', "'ll", 'text', 'you', 'when', 'priscilla', "'s", 'ready']
# ['i', 'taking', 'derek', 'amp', 'taylor', 'to', 'walmart', 'if', 'i', 'not', 'back', 'by', 'the', 'time', 'you', 'done', 'just', 'leave', 'the', 'mouse', 'on', 'my', 'desk', 'and', 'i', 'text', 'you', 'when', 'priscilla', 'ready']
# ['taking', 'derek', 'amp', 'taylor', 'walmart', 'back', 'time', 'done', 'leave', 'mouse', 'desk', 'text', 'priscilla', 'ready']
# ['hi', 'its', 'in', 'durban', 'are', 'you', 'still', 'on', 'this', 'number']
# ['hi', 'its', 'in', 'durban', 'are', 'you', 'still', 'on', 'this', 'number']
# ['hi', 'durban', 'still', 'number']
# ['ic', '.', 'there', 'are', 'a', 'lotta', 'childporn', 'cars', 'then', '.']
# ['ic', 'there', 'are', 'a', 'lotta', 'childporn', 'cars', 'then']
# ['ic', 'lotta', 'childporn', 'cars']
# ['had', 'your', 'contract', 'mobile', '11', 'mnths', '?', 'latest', 'motorola', ',', 'nokia', 'etc', '.', 'all', 'free', '!', 'double', 'mins', '&', 'text', 'on', 'orange', 'tariffs', '.', 'text', 'yes', 'for', 'callback', ',', 'no', 'to', 'remove', 'from', 'records', '.']
# ['had', 'your', 'contract', 'mobile', '11', 'mnths', 'latest', 'motorola', 'nokia', 'etc', 'all', 'free', 'double', 'mins', 'text', 'on', 'orange', 'tariffs', 'text', 'yes', 'for', 'callback', 'no', 'to', 'remove', 'from', 'records']
# ['contract', 'mobile', '11', 'mnths', 'latest', 'motorola', 'nokia', 'etc', 'free', 'double', 'mins', 'text', 'orange', 'tariffs', 'text', 'yes', 'callback', 'remove', 'records']
# ['no', ',', 'i', 'was', 'trying', 'it', 'all', 'weekend', ';', 'v']
# ['no', 'i', 'was', 'trying', 'it', 'all', 'weekend', 'v']
# ['trying', 'weekend', 'v']
# ['you', 'know', ',', 'wot', 'people', 'wear', '.', 't', 'shirts', ',', 'jumpers', ',', 'hat', ',', 'belt', ',', 'is', 'all', 'we', 'know', '.', 'we', 'r', 'at', 'cribbs']
# ['you', 'know', 'wot', 'people', 'wear', 't', 'shirts', 'jumpers', 'hat', 'belt', 'is', 'all', 'we', 'know', 'we', 'r', 'at', 'cribbs']
# ['know', 'wot', 'people', 'wear', 'shirts', 'jumpers', 'hat', 'belt', 'know', 'r', 'cribbs']
# ['cool', ',', 'what', 'time', 'you', 'think', 'you', 'can', 'get', 'here', '?']
# ['cool', 'what', 'time', 'you', 'think', 'you', 'can', 'get', 'here']
# ['cool', 'time', 'think', 'get']
# ['wen', 'did', 'you', 'get', 'so', 'spiritual', 'and', 'deep', '.', 'that', "'s", 'great']
# ['wen', 'did', 'you', 'get', 'so', 'spiritual', 'and', 'deep', 'that', 'great']
# ['wen', 'get', 'spiritual', 'deep', 'great']
# ['have', 'a', 'safe', 'trip', 'to', 'nigeria', '.', 'wish', 'you', 'happiness', 'and', 'very', 'soon', 'company', 'to', 'share', 'moments', 'with']
# ['have', 'a', 'safe', 'trip', 'to', 'nigeria', 'wish', 'you', 'happiness', 'and', 'very', 'soon', 'company', 'to', 'share', 'moments', 'with']
# ['safe', 'trip', 'nigeria', 'wish', 'happiness', 'soon', 'company', 'share', 'moments']
# ['well', 'keep', 'in', 'mind', 'i', "'ve", 'only', 'got', 'enough', 'gas', 'for', 'one', 'more', 'round', 'trip', 'barring', 'a', 'sudden', 'influx', 'of', 'cash']
# ['well', 'keep', 'in', 'mind', 'i', 'only', 'got', 'enough', 'gas', 'for', 'one', 'more', 'round', 'trip', 'barring', 'a', 'sudden', 'influx', 'of', 'cash']
# ['well', 'keep', 'mind', 'got', 'enough', 'gas', 'one', 'round', 'trip', 'barring', 'sudden', 'influx', 'cash']
# ['yeh', '.', 'indians', 'was', 'nice', '.', 'tho', 'it', 'did', 'kane', 'me', 'off', 'a', 'bit', 'he', 'he', '.', 'we', 'shud', 'go', 'out', '4', 'a', 'drink', 'sometime', 'soon', '.', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'a', 'laugh', 'soon', '.', 'love', 'pete', 'x', 'x']
# ['yeh', 'indians', 'was', 'nice', 'tho', 'it', 'did', 'kane', 'me', 'off', 'a', 'bit', 'he', 'he', 'we', 'shud', 'go', 'out', '4', 'a', 'drink', 'sometime', 'soon', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'a', 'laugh', 'soon', 'love', 'pete', 'x', 'x']
# ['yeh', 'indians', 'nice', 'tho', 'kane', 'bit', 'shud', 'go', '4', 'drink', 'sometime', 'soon', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'laugh', 'soon', 'love', 'pete', 'x', 'x']
# ['yes', 'i', 'have', '.', 'so', 'that', "'s", 'why', 'u', 'texted', '.', 'pshew', '...', 'missing', 'you', 'so', 'much']
# ['yes', 'i', 'have', 'so', 'that', 'why', 'u', 'texted', 'pshew', 'missing', 'you', 'so', 'much']
# ['yes', 'u', 'texted', 'pshew', 'missing', 'much']
# ['no', '.', 'i', 'meant', 'the', 'calculation', 'is', 'the', 'same', '.', 'that', '&', 'lt', ';', '#', '&', 'gt', ';', 'units', 'at', '&', 'lt', ';', '#', '&', 'gt', ';', '.', 'this', 'school', 'is', 'really', 'expensive', '.', 'have', 'you', 'started', 'practicing', 'your', 'accent', '.', 'because', 'its', 'important', '.', 'and', 'have', 'you', 'decided', 'if', 'you', 'are', 'doing', '4years', 'of', 'dental', 'school', 'or', 'if', 'you', "'ll", 'just', 'do', 'the', 'nmde', 'exam', '.']
# ['no', 'i', 'meant', 'the', 'calculation', 'is', 'the', 'same', 'that', 'lt', 'gt', 'units', 'at', 'lt', 'gt', 'this', 'school', 'is', 'really', 'expensive', 'have', 'you', 'started', 'practicing', 'your', 'accent', 'because', 'its', 'important', 'and', 'have', 'you', 'decided', 'if', 'you', 'are', 'doing', '4years', 'of', 'dental', 'school', 'or', 'if', 'you', 'just', 'do', 'the', 'nmde', 'exam']
# ['meant', 'calculation', 'lt', 'gt', 'units', 'lt', 'gt', 'school', 'really', 'expensive', 'started', 'practicing', 'accent', 'important', 'decided', '4years', 'dental', 'school', 'nmde', 'exam']
# ['if', 'you', 'are', "n't", 'here', 'in', 'the', 'next', '&', 'lt', ';', '#', '&', 'gt', ';', 'hours', 'imma', 'flip', 'my', 'shit']
# ['if', 'you', 'are', 'here', 'in', 'the', 'next', 'lt', 'gt', 'hours', 'imma', 'flip', 'my', 'shit']
# ['next', 'lt', 'gt', 'hours', 'imma', 'flip', 'shit']
# ['anything', 'lor', '.', 'juz', 'both', 'of', 'us', 'lor', '.']
# ['anything', 'lor', 'juz', 'both', 'of', 'us', 'lor']
# ['anything', 'lor', 'juz', 'us', 'lor']
# ['get', 'me', 'out', 'of', 'this', 'dump', 'heap', '.', 'my', 'mom', 'decided', 'to', 'come', 'to', 'lowes', '.', 'boring', '.']
# ['get', 'me', 'out', 'of', 'this', 'dump', 'heap', 'my', 'mom', 'decided', 'to', 'come', 'to', 'lowes', 'boring']
# ['get', 'dump', 'heap', 'mom', 'decided', 'come', 'lowes', 'boring']
# ['ok', 'lor', '...', 'sony', 'ericsson', 'salesman', '...', 'i', 'ask', 'shuhui', 'then', 'she', 'say', 'quite', 'gd', '2', 'use', 'so', 'i', 'considering', '...']
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'i', 'ask', 'shuhui', 'then', 'she', 'say', 'quite', 'gd', '2', 'use', 'so', 'i', 'considering']
# ['ok', 'lor', 'sony', 'ericsson', 'salesman', 'ask', 'shuhui', 'say', 'quite', 'gd', '2', 'use', 'considering']
# ['ard', '6', 'like', 'dat', 'lor', '.']
# ['ard', '6', 'like', 'dat', 'lor']
# ['ard', '6', 'like', 'dat', 'lor']
# ['why', 'do', "n't", 'you', 'wait', "'til", 'at', 'least', 'wednesday', 'to', 'see', 'if', 'you', 'get', 'your', '.']
# ['why', 'do', 'you', 'wait', 'at', 'least', 'wednesday', 'to', 'see', 'if', 'you', 'get', 'your']
# ['wait', 'least', 'wednesday', 'see', 'get']
# ['huh', 'y', 'lei', '...']
# ['huh', 'y', 'lei']
# ['huh', 'lei']
# ['reminder', 'from', 'o2', ':', 'to', 'get', '2.50', 'pounds', 'free', 'call', 'credit', 'and', 'details', 'of', 'great', 'offers', 'pls', 'reply', '2', 'this', 'text', 'with', 'your', 'valid', 'name', ',', 'house', 'no', 'and', 'postcode']
# ['reminder', 'from', 'o2', 'to', 'get', 'pounds', 'free', 'call', 'credit', 'and', 'details', 'of', 'great', 'offers', 'pls', 'reply', '2', 'this', 'text', 'with', 'your', 'valid', 'name', 'house', 'no', 'and', 'postcode']
# ['reminder', 'o2', 'get', 'pounds', 'free', 'call', 'credit', 'details', 'great', 'offers', 'pls', 'reply', '2', 'text', 'valid', 'name', 'house', 'postcode']
# ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', '2', 'contact', 'u.', 'u', 'have', 'won', 'the', 'å£750', 'pound', 'prize', '.', '2', 'claim', 'is', 'easy', ',', 'call', '087187272008', 'now1', '!', 'only', '10p', 'per', 'minute', '.', 'bt-national-rate', '.']
# ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', '2', 'contact', 'u', 'have', 'won', 'the', 'pound', 'prize', '2', 'claim', 'is', 'easy', 'call', '087187272008', 'now1', 'only', '10p', 'per', 'minute']
# ['2nd', 'time', 'tried', '2', 'contact', 'u', 'pound', 'prize', '2', 'claim', 'easy', 'call', '087187272008', 'now1', '10p', 'per', 'minute']
# ['will', 'ì_', 'b', 'going', 'to', 'esplanade', 'fr', 'home', '?']
# ['will', 'b', 'going', 'to', 'esplanade', 'fr', 'home']
# ['b', 'going', 'esplanade', 'fr', 'home']
# ['pity', ',', '*', 'was', 'in', 'mood', 'for', 'that', '.', 'so', '...', 'any', 'other', 'suggestions', '?']
# ['pity', 'was', 'in', 'mood', 'for', 'that', 'so', 'any', 'other', 'suggestions']
# ['pity', 'mood', 'suggestions']
# ['the', 'guy', 'did', 'some', 'bitching', 'but', 'i', 'acted', 'like', 'i', "'d", 'be', 'interested', 'in', 'buying', 'something', 'else', 'next', 'week', 'and', 'he', 'gave', 'it', 'to', 'us', 'for', 'free']
# ['the', 'guy', 'did', 'some', 'bitching', 'but', 'i', 'acted', 'like', 'i', 'be', 'interested', 'in', 'buying', 'something', 'else', 'next', 'week', 'and', 'he', 'gave', 'it', 'to', 'us', 'for', 'free']
# ['guy', 'bitching', 'acted', 'like', 'interested', 'buying', 'something', 'else', 'next', 'week', 'gave', 'us', 'free']
# ['rofl', '.', 'its', 'true', 'to', 'its', 'name']
# ['rofl', 'its', 'true', 'to', 'its', 'name']
# ['rofl', 'true', 'name']

# %%
df.head()

# %%
# ! pip install WordCloud

# %%
from wordcloud import WordCloud

# %%
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='black')

# %%
df[df['target']==1]

# %%
# corpus
df[df['target']==1]['transformed_text'].str.cat(sep=" ")

# %%
spam_wc=wc.generate(df[df['target']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(dpi=500)
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['target']==0]['transformed_text'].str.cat(sep='" "'))

# %%
plt.figure(dpi=500)
plt.imshow(ham_wc)

# %%
# displaying the top 30 words in spam sms

# %%
df[df['target']==1]['transformed_text'].tolist()

# %%
df[df['target']==1]['transformed_text'].tolist()

# %%
spam_corpus=[]
for msg in df[df['target']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)
        
# print(spam_corpus)

# %%
spam_corpus

# %%
# for counting the words
from collections import Counter

# %%
spam_df=pd.DataFrame(Counter(spam_corpus).most_common()).rename(columns={0:'words',1:'count'})
spam_df

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='words',y='count',data=spam_df.head(30))
plt.xticks(rotation='vertical')
plt.show()

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
ham_corpus

# %%
ham_df=pd.DataFrame(Counter(ham_corpus).most_common()).rename(columns={0:'words',1:'count'})
ham_df

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='words',y='count',data=ham_df.head(30))
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # 4. Feature Engineering

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df['transformed_text']).toarray()
X

# %%
X.shape

# %%
y=df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# # 5. Model Building

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred_test1=gnb.predict(x_test)
y_pred_train1=gnb.predict(x_train)
print('Testing Accuracy',accuracy_score(y_test,y_pred_test1))
print('Trainning_Accuracy',accuracy_score(y_train,y_pred_train1))
print('Precision_Score',precision_score(y_train,y_pred_train1))
print('Confusion_matrix\n',confusion_matrix(y_train,y_pred_train1))

# %%
# performance check metrics for regression -----------r2_score
# performance check metrics for classification--------accuracy_score (confusion metrics)
#                                                     (TP+TN)/(TP+FP+TN+FN)

# %%
mnb.fit(x_train,y_train)
y_pred_test2=mnb.predict(x_test)
y_pred_train2=mnb.predict(x_train)
print('Testing Accuracy',accuracy_score(y_test,y_pred_test2))
print('Trainning_Accuracy',accuracy_score(y_train,y_pred_train2))
print('Precision_Score',precision_score(y_train,y_pred_train2))
print('Confusion_matrix\n',confusion_matrix(y_train,y_pred_train2))

# %%
bnb.fit(x_train,y_train)
y_pred_test3=bnb.predict(x_test)
y_pred_train3=bnb.predict(x_train)
print('Testing Accuracy',accuracy_score(y_test,y_pred_test3))
print('Trainning_Accuracy',accuracy_score(y_train,y_pred_train3))
print('Precision_Score',precision_score(y_train,y_pred_train3))
print('Confusion_matrix\n',confusion_matrix(y_train,y_pred_train3))

# %%
svc = SVC()
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression()
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
clfs.items()

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred_test = clf.predict(X_test)
    y_pred_train = clf.predict(X_train)

    accuracy_test = accuracy_score(y_test,y_pred_test)
    accuracy_train = accuracy_score(y_train,y_pred_train)

    
    return accuracy_test,accuracy_train

# %%
train_classifier(svc,x_train,y_train,x_test,y_test)

# %%
accuracy_train1 = []
accuracy_test1 = []

precision_scores = []

for name,clf in clfs.items():
    
    accuracy_test,accuracy_train,precision = train_classifier(clf, x_train,y_train,x_test,y_test)
    
    print("For ",name)
    print("Training Accuracy - ",accuracy_train)
    print("Testing Accuracy - ",accuracy_test)
    print("Precision - ",precision)
    
    accuracy_train1.append(accuracy_train)
    accuracy_test1.append(accuracy_test)

    precision_scores.append(precision)

# %%
performance_df =pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_train':accuracy_train1,'Accuracy_test':accuracy_test1})
performance_df.sort_values(by='Accuracy_test',ascending=False)

# %%
performance_df.sort_values('Precision',ascending=False)

# %%
# improving model_performances
# 1. Change the max_features parameter of TfIdf

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
